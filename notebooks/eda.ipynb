# %% [markdown]
# # 금융 데이터 탐색적 데이터 분석 (EDA)
#
# 이 노트북은 KB 금융 지식 그래프를 위한 데이터 파일들을 탐색합니다.
#
# ## 데이터 파일 구조
# - 파일 구분자: `^`
# - 파일명에서 앞의 'XX_' prefix를 제외하면 테이블명
# - 각 테이블별 스키마는 eda.md 파일 참조

# %%
import pandas as pd
import os
import glob
from pathlib import Path

# 데이터 디렉토리 경로 설정
data_dir = Path('../data')
print(f"데이터 디렉토리: {data_dir.resolve()}")
# Out:
# 데이터 디렉토리: /Users/toby/prog/kt/202512_KB/kt-fin-kg/data

# %%
# 데이터 파일 목록 확인
data_files = sorted(list(data_dir.glob('*.dat')))
print(f"총 {len(data_files)}개의 데이터 파일 발견:")
for file in data_files:
    size_mb = file.stat().st_size / (1024 * 1024)
    print(f"  {file.name} ({size_mb:.2f} MB)")
# Out:
# 총 12개의 데이터 파일 발견:
#   01_CORP_PROF.dat (22.34 MB)
#   02_CUST_MST.dat (23.34 MB)
#   03_CORP_BIZ_MAP.dat (9.58 MB)
#   04_LOAN_CTRT.dat (2.49 MB)
#   05_PRD_MST.dat (0.09 MB)
#   06_COLL_SET.dat (2.94 MB)
#   07_CAI_TXN.dat (7.58 MB)
#   08_KSIC_CD.dat (0.16 MB)
#   09_ADM_DONG_CD.dat (1.48 MB)
#   10_ZIP_CD.dat (1.89 MB)
#   11_BRANCH_CD.dat (0.04 MB)
#   12_CMN_CD.dat (0.02 MB)

# %%
# 각 파일별로 3개 샘플 데이터 출력하는 함수
def detect_encoding(file_path):
    """
    파일의 인코딩을 자동으로 감지하는 함수
    """
    import chardet
    
    try:
        with open(file_path, 'rb') as f:
            raw_data = f.read(10000)  # 첫 10KB만 읽어서 인코딩 감지
            result = chardet.detect(raw_data)
            return result['encoding']
    except:
        return 'utf-8'

def display_file_samples(file_path, n_samples=3):
    """
    데이터 파일에서 샘플 데이터를 읽어서 출력
    
    Args:
        file_path: 데이터 파일 경로
        n_samples: 출력할 샘플 개수
    """
    try:
        # 파일명에서 테이블명 추출 (앞의 숫자_를 제거)
        table_name = file_path.name.split('_', 1)[1].replace('.dat', '')
        
        print(f"\n{'='*60}")
        print(f"테이블: {table_name}")
        print(f"파일: {file_path.name}")
        print(f"{'='*60}")
        
        # 파일 크기 정보
        size_mb = file_path.stat().st_size / (1024 * 1024)
        print(f"파일 크기: {size_mb:.2f} MB")
        
        # 인코딩 감지 및 설정
        encodings_to_try = ['cp949', 'euc-kr', 'utf-8', 'latin-1']
        encoding_used = None
        first_line = None
        
        for encoding in encodings_to_try:
            try:
                with open(file_path, 'r', encoding=encoding) as f:
                    first_line = f.readline().strip()
                    encoding_used = encoding
                    break
            except UnicodeDecodeError:
                continue
        
        if first_line is None:
            print("파일 인코딩을 감지할 수 없습니다.")
            return
            
        print(f"사용된 인코딩: {encoding_used}")
        
        # 컬럼 수 확인
        column_count = len(first_line.split('^'))
        print(f"컬럼 수: {column_count}")
        
        # 데이터 읽기 (구분자 ^, 헤더 없음)
        df = pd.read_csv(file_path, sep='^', header=None, nrows=n_samples, encoding=encoding_used)
        
        print(f"\n샘플 데이터 ({n_samples}행):")
        print("-" * 60)
        
        # 데이터 출력 (각 행을 세로로 표시)
        for idx, row in df.iterrows():
            print(f"\n[샘플 {idx + 1}]")
            for col_idx, value in enumerate(row):
                print(f"  컬럼 {col_idx + 1}: {value}")
                
    except Exception as e:
        print(f"오류 발생: {e}")
        print(f"파일을 읽는 중 문제가 발생했습니다: {file_path.name}")

# %%
# 모든 데이터 파일의 샘플 데이터 출력
print("KB 금융 데이터 샘플 분석")
print("=" * 80)

for file_path in data_files:
    display_file_samples(file_path, n_samples=3)
# Out:
# KB 금융 데이터 샘플 분석
# ================================================================================
#
# ============================================================
# 테이블: CORP_PROF
# 파일: 01_CORP_PROF.dat
# ============================================================
# 파일 크기: 22.34 MB
# 사용된 인코딩: cp949
# 컬럼 수: 7
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 6
#   컬럼 2: 롯데**
#   컬럼 3: G47111
#   컬럼 4: 1048126067
#   컬럼 5: 4533
#   컬럼 6: 1101110000086
#   컬럼 7: nan
#
# [샘플 2]
#   컬럼 1: 7
#   컬럼 2: 동양**
#   컬럼 3: F42311
#   컬럼 4: 2018148663
#   컬럼 5: 4557
#   컬럼 6: 1101110000309
#   컬럼 7: nan
#
# [샘플 3]
#   컬럼 1: 9
#   컬럼 2: 모라*
#   컬럼 3: C14300
#   컬럼 4: 1098109665
#   컬럼 5: 3186
#   컬럼 6: 1101110000531
#   컬럼 7: nan
#
# ============================================================
# 테이블: CUST_MST
# 파일: 02_CUST_MST.dat
# ============================================================
# 파일 크기: 23.34 MB
# 사용된 인코딩: cp949
# 컬럼 수: 5
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 7000000180.0
#   컬럼 2: 1018100452.0
#   컬럼 3: 2.0
#   컬럼 4: 4.0
#   컬럼 5: nan
#
# [샘플 2]
#   컬럼 1: 7000000233.0
#   컬럼 2: 1018110436.0
#   컬럼 3: 2.0
#   컬럼 4: 4.0
#   컬럼 5: nan
#
# [샘플 3]
#   컬럼 1: 7000000291.0
#   컬럼 2: 1018118476.0
#   컬럼 3: 2.0
#   컬럼 4: 4.0
#   컬럼 5: nan
#
# ============================================================
# 테이블: CORP_BIZ_MAP
# 파일: 03_CORP_BIZ_MAP.dat
# ============================================================
# 파일 크기: 9.58 MB
# 사용된 인코딩: cp949
# 컬럼 수: 3
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 7000000180.0
#   컬럼 2: 7000000180.0
#   컬럼 3: nan
#
# [샘플 2]
#   컬럼 1: 7000000233.0
#   컬럼 2: 7000000233.0
#   컬럼 3: nan
#
# [샘플 3]
#   컬럼 1: 7000000291.0
#   컬럼 2: 7000000291.0
#   컬럼 3: nan
#
# ============================================================
# 테이블: LOAN_CTRT
# 파일: 04_LOAN_CTRT.dat
# ============================================================
# 파일 크기: 2.49 MB
# 사용된 인코딩: cp949
# 컬럼 수: 14
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 102694812380946
#   컬럼 2: 0
#   컬럼 3: 8004262537
#   컬럼 4: 1
#   컬럼 5: 2534P0500001
#   컬럼 6: 20080710
#   컬럼 7: 20260710
#   컬럼 8: 7797
#   컬럼 9: KRW
#   컬럼 10: 3218000000.0
#   컬럼 11: 1
#   컬럼 12: 0
#   컬럼 13: nan
#   컬럼 14: nan
#
# [샘플 2]
#   컬럼 1: 102694812716043
#   컬럼 2: 0
#   컬럼 3: 7004619452
#   컬럼 4: 1
#   컬럼 5: 2534P0500001
#   컬럼 6: 20191111
#   컬럼 7: 20251111
#   컬럼 8: 936
#   컬럼 9: KRW
#   컬럼 10: 1460000000.0
#   컬럼 11: 1
#   컬럼 12: 0
#   컬럼 13: nan
#   컬럼 14: nan
#
# [샘플 3]
#   컬럼 1: 103474812548838
#   컬럼 2: 0
#   컬럼 3: 8031175527
#   컬럼 4: 1
#   컬럼 5: 2534P0500001
#   컬럼 6: 20170424
#   컬럼 7: 20260723
#   컬럼 8: 3449
#   컬럼 9: KRW
#   컬럼 10: 6850000000.0
#   컬럼 11: 1
#   컬럼 12: 0
#   컬럼 13: nan
#   컬럼 14: nan
#
# ============================================================
# 테이블: PRD_MST
# 파일: 05_PRD_MST.dat
# ============================================================
# 파일 크기: 0.09 MB
# 사용된 인코딩: cp949
# 컬럼 수: 7
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 1
#   컬럼 2: 250110100001
#   컬럼 3: 일반예금담보대출
#   컬럼 4: 1
#   컬럼 5: 19951110
#   컬럼 6: 99991231
#   컬럼 7: nan
#
# [샘플 2]
#   컬럼 1: 1
#   컬럼 2: 250110100003
#   컬럼 3: 일반예금담보대출(시설)
#   컬럼 4: 1
#   컬럼 5: 19000101
#   컬럼 6: 20071231
#   컬럼 7: nan
#
# [샘플 3]
#   컬럼 1: 1
#   컬럼 2: 250110100004
#   컬럼 3: 일반예금담보대출(공공및기타운전)
#   컬럼 4: 1
#   컬럼 5: 19000101
#   컬럼 6: 99991231
#   컬럼 7: nan
#
# ============================================================
# 테이블: COLL_SET
# 파일: 06_COLL_SET.dat
# ============================================================
# 파일 크기: 2.94 MB
# 사용된 인코딩: cp949
# 컬럼 수: 8
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 122254804035537.0
#   컬럼 2: 234000000.0
#   컬럼 3: 850000000.0
#   컬럼 4: 27.53
#   컬럼 5: 201881240.0
#   컬럼 6: 4128111100.0
#   컬럼 7: 121.0
#   컬럼 8: nan
#
# [샘플 2]
#   컬럼 1: 122254804038153.0
#   컬럼 2: 1266000000.0
#   컬럼 3: 3506000000.0
#   컬럼 4: 36.11
#   컬럼 5: 202883542.0
#   컬럼 6: 1114013600.0
#   컬럼 7: 151.0
#   컬럼 8: nan
#
# [샘플 3]
#   컬럼 1: 122254804039800.0
#   컬럼 2: 413000000.0
#   컬럼 3: 550000000.0
#   컬럼 4: 75.09
#   컬럼 5: 201040733.0
#   컬럼 6: 4127310100.0
#   컬럼 7: 121.0
#   컬럼 8: nan
#
# ============================================================
# 테이블: CAI_TXN
# 파일: 07_CAI_TXN.dat
# ============================================================
# 파일 크기: 7.58 MB
# 사용된 인코딩: cp949
# 컬럼 수: 4
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 1018100452.0
#   컬럼 2: 2018132195.0
#   컬럼 3: 53000.0
#   컬럼 4: nan
#
# [샘플 2]
#   컬럼 1: 1018102940.0
#   컬럼 2: 1018116406.0
#   컬럼 3: 5279740000.0
#   컬럼 4: nan
#
# [샘플 3]
#   컬럼 1: 1018106586.0
#   컬럼 2: 1218110385.0
#   컬럼 3: 8180000.0
#   컬럼 4: nan
#
# ============================================================
# 테이블: KSIC_CD
# 파일: 08_KSIC_CD.dat
# ============================================================
# 파일 크기: 0.16 MB
# 사용된 인코딩: cp949
# 컬럼 수: 11
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 1110
#   컬럼 2: 곡물 및 기타 식량작물 재배업
#   컬럼 3: 111
#   컬럼 4: 곡물 및 기타 식량작물 재배업
#   컬럼 5: 11
#   컬럼 6: 작물 재배업
#   컬럼 7: 1
#   컬럼 8: 농업
#   컬럼 9: A
#   컬럼 10: 농업, 임업 및 어업(01~03)
#   컬럼 11: nan
#
# [샘플 2]
#   컬럼 1: 1121
#   컬럼 2: 채소작물 재배업
#   컬럼 3: 112
#   컬럼 4: 채소, 화훼작물 및 종묘 재배업
#   컬럼 5: 11
#   컬럼 6: 작물 재배업
#   컬럼 7: 1
#   컬럼 8: 농업
#   컬럼 9: A
#   컬럼 10: 농업, 임업 및 어업(01~03)
#   컬럼 11: nan
#
# [샘플 3]
#   컬럼 1: 1122
#   컬럼 2: 화훼작물 재배업
#   컬럼 3: 112
#   컬럼 4: 채소, 화훼작물 및 종묘 재배업
#   컬럼 5: 11
#   컬럼 6: 작물 재배업
#   컬럼 7: 1
#   컬럼 8: 농업
#   컬럼 9: A
#   컬럼 10: 농업, 임업 및 어업(01~03)
#   컬럼 11: nan
#
# ============================================================
# 테이블: ADM_DONG_CD
# 파일: 09_ADM_DONG_CD.dat
# ============================================================
# 파일 크기: 1.48 MB
# 사용된 인코딩: cp949
# 컬럼 수: 12
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 11
#   컬럼 2: 0
#   컬럼 3: 0
#   컬럼 4: 0
#   컬럼 5: 0
#   컬럼 6: 9999
#   컬럼 7: 1100000000
#   컬럼 8: 서울특별시
#   컬럼 9: nan
#   컬럼 10: nan
#   컬럼 11: nan
#   컬럼 12: nan
#
# [샘플 2]
#   컬럼 1: 11
#   컬럼 2: 11
#   컬럼 3: 0
#   컬럼 4: 0
#   컬럼 5: 0
#   컬럼 6: 9999
#   컬럼 7: 1111000000
#   컬럼 8: 서울특별시
#   컬럼 9: 종로구
#   컬럼 10: nan
#   컬럼 11: nan
#   컬럼 12: nan
#
# [샘플 3]
#   컬럼 1: 11
#   컬럼 2: 11
#   컬럼 3: 0
#   컬럼 4: 101
#   컬럼 5: 0
#   컬럼 6: 9999
#   컬럼 7: 1111010100
#   컬럼 8: 서울특별시
#   컬럼 9: 종로구
#   컬럼 10: 청운동
#   컬럼 11: nan
#   컬럼 12: nan
#
# ============================================================
# 테이블: ZIP_CD
# 파일: 10_ZIP_CD.dat
# ============================================================
# 파일 크기: 1.89 MB
# 사용된 인코딩: cp949
# 컬럼 수: 5
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 0
#   컬럼 2: 주소미상
#   컬럼 3: 주소정비요
#   컬럼 4: nan
#   컬럼 5: nan
#
# [샘플 2]
#   컬럼 1: 1000
#   컬럼 2: 서울
#   컬럼 3: 강북구
#   컬럼 4: 우이동
#   컬럼 5: nan
#
# [샘플 3]
#   컬럼 1: 1001
#   컬럼 2: 서울
#   컬럼 3: 강북구
#   컬럼 4: 우이동
#   컬럼 5: nan
#
# ============================================================
# 테이블: BRANCH_CD
# 파일: 11_BRANCH_CD.dat
# ============================================================
# 파일 크기: 0.04 MB
# 사용된 인코딩: cp949
# 컬럼 수: 6
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 3
#   컬럼 2: WM추진부
#   컬럼 3: 7331
#   컬럼 4: 1
#   컬럼 5:
#   컬럼 6: nan
#
# [샘플 2]
#   컬럼 1: 8
#   컬럼 2: 본부
#   컬럼 3: 7331
#   컬럼 4: 1
#   컬럼 5:
#   컬럼 6: nan
#
# [샘플 3]
#   컬럼 1: 11
#   컬럼 2: 비서실
#   컬럼 3: 7332
#   컬럼 4: 1
#   컬럼 5:
#   컬럼 6: nan
#
# ============================================================
# 테이블: CMN_CD
# 파일: 12_CMN_CD.dat
# ============================================================
# 파일 크기: 0.02 MB
# 사용된 인코딩: cp949
# 컬럼 수: 6
#
# 샘플 데이터 (3행):
# ------------------------------------------------------------
#
# [샘플 1]
#   컬럼 1: 100233000
#   컬럼 2: 1
#   컬럼 3: 19630201
#   컬럼 4: 99991231
#   컬럼 5: 주민등록번호
#   컬럼 6: nan
#
# [샘플 2]
#   컬럼 1: 100233000
#   컬럼 2: 2
#   컬럼 3: 19630201
#   컬럼 4: 99991231
#   컬럼 5: 사업자등록번호
#   컬럼 6: nan
#
# [샘플 3]
#   컬럼 1: 100233000
#   컬럼 2: 3
#   컬럼 3: 19630201
#   컬럼 4: 99991231
#   컬럼 5: 여권번호
#   컬럼 6: nan

# %%
# 전체 데이터 파일 요약 정보
print("\n" + "=" * 80)
print("데이터 파일 요약")
print("=" * 80)

total_size = 0
file_info = []

for file_path in data_files:
    size_mb = file_path.stat().st_size / (1024 * 1024)
    total_size += size_mb
    
    # 행 수 계산 (빠른 계산을 위해 wc 명령 사용)
    try:
        import subprocess
        result = subprocess.run(['wc', '-l', str(file_path)], 
                              capture_output=True, text=True)
        line_count = int(result.stdout.split()[0])
    except:
        line_count = "N/A"
    
    # 인코딩 확인
    encodings_to_try = ['cp949', 'euc-kr', 'utf-8', 'latin-1']
    encoding_used = 'unknown'
    
    for encoding in encodings_to_try:
        try:
            with open(file_path, 'r', encoding=encoding) as f:
                f.readline()  # 첫 줄만 읽어서 테스트
                encoding_used = encoding
                break
        except UnicodeDecodeError:
            continue
    
    table_name = file_path.name.split('_', 1)[1].replace('.dat', '')
    file_info.append({
        '테이블명': table_name,
        '파일명': file_path.name,
        '크기(MB)': f"{size_mb:.2f}",
        '행수': line_count,
        '인코딩': encoding_used
    })

# 요약 테이블 출력
summary_df = pd.DataFrame(file_info)
print(summary_df.to_string(index=False))
print(f"\n총 파일 크기: {total_size:.2f} MB")
# Out:
# ================================================================================
# 데이터 파일 요약
# ================================================================================
#         테이블명                 파일명 크기(MB)     행수   인코딩
#    CORP_PROF    01_CORP_PROF.dat  22.34 395108 cp949
#     CUST_MST     02_CUST_MST.dat  23.34 831796 cp949
# CORP_BIZ_MAP 03_CORP_BIZ_MAP.dat   9.58 436688 cp949
#    LOAN_CTRT    04_LOAN_CTRT.dat   2.49  25203 cp949
#      PRD_MST      05_PRD_MST.dat   0.09   1342 cp949
#     COLL_SET     06_COLL_SET.dat   2.94  25203 cp949
#      CAI_TXN      07_CAI_TXN.dat   7.58 254928 cp949
#      KSIC_CD      08_KSIC_CD.dat   0.16   1205 cp949
#  ADM_DONG_CD  09_ADM_DONG_CD.dat   1.48  25071 cp949
#       ZIP_CD       10_ZIP_CD.dat   1.89  69675 cp949
#    BRANCH_CD    11_BRANCH_CD.dat   0.04   1130 cp949
#       CMN_CD       12_CMN_CD.dat   0.02    406 cp949
#
# 총 파일 크기: 71.94 MB
# python(13038) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13040) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13041) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13042) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13043) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13044) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13045) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13046) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13047) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13048) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13049) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(13050) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
# df_total 딕셔너리 생성 - 모든 데이터 파일을 로드
def create_df_total_dict(data_dir):
    """
    모든 .dat 파일을 읽어서 df_total 딕셔너리 생성
    """
    df_total = {}
    data_files = sorted(list(data_dir.glob('*.dat')))
    
    print("데이터 로딩 시작...")
    print("=" * 50)
    
    for file_path in data_files:
        try:
            # 테이블명 추출
            table_name = file_path.name.split('_', 1)[1].replace('.dat', '')
            
            # 인코딩 감지 및 데이터 로드
            encodings_to_try = ['cp949', 'euc-kr', 'utf-8', 'latin-1']
            encoding_used = None
            
            for encoding in encodings_to_try:
                try:
                    df = pd.read_csv(file_path, sep='^', header=None, encoding=encoding)
                    encoding_used = encoding
                    break
                except UnicodeDecodeError:
                    continue
            
            if df is not None:
                df_total[table_name] = df
                print(f"✓ {table_name}: {df.shape[0]:,}행 x {df.shape[1]}열 (인코딩: {encoding_used})")
            else:
                print(f"✗ {table_name}: 로드 실패")
                
        except Exception as e:
            print(f"✗ {file_path.name}: 오류 - {e}")
    
    print("=" * 50)
    print(f"총 {len(df_total)}개 테이블 로드 완료")
    return df_total

# 실제 데이터 로드 실행
df_total = create_df_total_dict(data_dir)
print(f"\n로드된 테이블: {list(df_total.keys())}")
# Out:
# 데이터 로딩 시작...
# ==================================================
# ✓ CORP_PROF: 395,108행 x 7열 (인코딩: cp949)
# ✓ CUST_MST: 831,796행 x 5열 (인코딩: cp949)
# ✓ CORP_BIZ_MAP: 436,688행 x 3열 (인코딩: cp949)
# ✓ LOAN_CTRT: 25,203행 x 14열 (인코딩: cp949)
# ✓ PRD_MST: 1,342행 x 7열 (인코딩: cp949)
# ✓ COLL_SET: 25,203행 x 8열 (인코딩: cp949)
# ✓ CAI_TXN: 254,928행 x 4열 (인코딩: cp949)
# ✓ KSIC_CD: 1,205행 x 11열 (인코딩: cp949)
# ✓ ADM_DONG_CD: 25,071행 x 12열 (인코딩: cp949)
# ✓ ZIP_CD: 69,675행 x 5열 (인코딩: cp949)
# ✓ BRANCH_CD: 1,130행 x 6열 (인코딩: cp949)
# ✓ CMN_CD: 406행 x 6열 (인코딩: cp949)
# ==================================================
# 총 12개 테이블 로드 완료
#
# 로드된 테이블: ['CORP_PROF', 'CUST_MST', 'CORP_BIZ_MAP', 'LOAN_CTRT', 'PRD_MST', 'COLL_SET', 'CAI_TXN', 'KSIC_CD', 'ADM_DONG_CD', 'ZIP_CD', 'BRANCH_CD', 'CMN_CD']

# %% [markdown]
# ## EDA 결과 요약 및 인사이트
#
# 위의 분석을 통해 다음과 같은 인사이트를 얻을 수 있습니다:
#
# ### 주요 발견사항
# 1. **데이터 품질**: 각 테이블의 결측값 비율과 중복 데이터 현황
# 2. **변수 유형**: Nominal vs Numerical 변수의 분포와 특성
# 3. **테이블 관계**: 잠재적 외래키 관계 및 테이블 간 연결점
# 4. **데이터 분포**: 각 변수별 분포 특성과 이상치 현황
#
# ### 추가 분석 권장사항
# - 시간 시계열 분석 (날짜 컬럼이 있는 경우)
# - 지리적 분석 (주소/지역 코드 기반)
# - 고객 세그멘테이션 분석
# - 위험 요소 분석 (대출, 담보 관련)

# %%
# 데이터 품질 및 관계 분석 실행
try:
    # 데이터 품질 분석
    quality_results = analyze_data_quality(df_total)
    
    # 테이블 간 관계 분석
    relationships = analyze_table_relationships(df_total)
    
except NameError:
    print("df_total 딕셔너리가 정의되지 않았습니다.")
    print("먼저 데이터를 로드해주세요.")
except Exception as e:
    print(f"분석 중 오류 발생: {e}")
# Out:
# ################################################################################
# 데이터 품질 종합 분석
# ################################################################################
#         테이블명      행수  컬럼수      총_셀수   결측_셀수 결측_비율(%) 중복_행수 중복_비율(%)
#    CORP_PROF 395,108    7 2,765,756 395,108    14.29     0     0.00
#     CUST_MST 831,796    5 4,158,980 831,796    20.00     0     0.00
# CORP_BIZ_MAP 436,688    3 1,310,064 436,688    33.33     0     0.00
#    LOAN_CTRT  25,203   14   352,842  49,079    13.91     0     0.00
#      PRD_MST   1,342    7     9,394   1,342    14.29     0     0.00
#     COLL_SET  25,203    8   201,624  25,203    12.50     0     0.00
#      CAI_TXN 254,928    4 1,019,712 254,928    25.00     0     0.00
#      KSIC_CD   1,205   11    13,255   1,205     9.09     0     0.00
#  ADM_DONG_CD  25,071   12   300,852  31,702    10.54     0     0.00
#       ZIP_CD  69,675    5   348,375  69,949    20.08     0     0.00
#    BRANCH_CD   1,130    6     6,780   1,130    16.67     0     0.00
#       CMN_CD     406    6     2,436     406    16.67     0     0.00
#
# ################################################################################
# 테이블 간 관계 분석
# ################################################################################
# 잠재적 테이블 관계:
#         테이블1  컬럼1         테이블2 컬럼2   공통값수  겹침비율
#    CORP_PROF  컬럼4     CUST_MST 컬럼2 395108 1.000
#     CUST_MST  컬럼1 CORP_BIZ_MAP 컬럼1 436688 1.000
#     COLL_SET  컬럼7  ADM_DONG_CD 컬럼4     32 1.000
#     COLL_SET  컬럼6  ADM_DONG_CD 컬럼7   3812 1.000
#    LOAN_CTRT  컬럼8    BRANCH_CD 컬럼1    440 1.000
#    LOAN_CTRT 컬럼10     COLL_SET 컬럼2   5630 1.000
#    CORP_PROF  컬럼6     CUST_MST 컬럼2 395108 1.000
#     CUST_MST  컬럼1 CORP_BIZ_MAP 컬럼2 436688 1.000
#    LOAN_CTRT  컬럼5      PRD_MST 컬럼2    277 1.000
#  ADM_DONG_CD 컬럼10       ZIP_CD 컬럼4   4009 0.998
#    LOAN_CTRT  컬럼1     COLL_SET 컬럼1  23876 0.947
#     CUST_MST  컬럼2      CAI_TXN 컬럼1  72546 0.911
#    CORP_PROF  컬럼4      CAI_TXN 컬럼1  70560 0.887
#      KSIC_CD  컬럼7    BRANCH_CD 컬럼4     15 0.882
#    CORP_PROF  컬럼5    BRANCH_CD 컬럼3    700 0.879
#  ADM_DONG_CD  컬럼9       ZIP_CD 컬럼3    207 0.852
#      KSIC_CD  컬럼7  ADM_DONG_CD 컬럼1     17 0.850
#     CUST_MST  컬럼2      CAI_TXN 컬럼2  69564 0.849
#      KSIC_CD  컬럼7  ADM_DONG_CD 컬럼5     40 0.800
#    CORP_PROF  컬럼4      CAI_TXN 컬럼2  65260 0.797
#     CUST_MST  컬럼1    LOAN_CTRT 컬럼3  11475 0.796
# CORP_BIZ_MAP  컬럼2    LOAN_CTRT 컬럼3  11475 0.796
# CORP_BIZ_MAP  컬럼1    LOAN_CTRT 컬럼3  11475 0.796
#    CORP_PROF  컬럼1  ADM_DONG_CD 컬럼1     15 0.750
#      KSIC_CD  컬럼7  ADM_DONG_CD 컬럼2     54 0.740
#       ZIP_CD  컬럼1    BRANCH_CD 컬럼5    105 0.665
#    LOAN_CTRT  컬럼8    BRANCH_CD 컬럼5    103 0.652
#    LOAN_CTRT  컬럼8       ZIP_CD 컬럼1    275 0.625
#      KSIC_CD  컬럼3       ZIP_CD 컬럼1    307 0.613
#    CORP_PROF  컬럼1  ADM_DONG_CD 컬럼4     70 0.569
#    LOAN_CTRT 컬럼10     COLL_SET 컬럼3   3192 0.567
#    CORP_PROF  컬럼1  ADM_DONG_CD 컬럼5     28 0.560
#    CORP_PROF  컬럼5       ZIP_CD 컬럼1  26544 0.550
#    CORP_PROF  컬럼5    BRANCH_CD 컬럼5     84 0.532
#    CORP_PROF  컬럼1      KSIC_CD 컬럼7     41 0.532
#    CORP_PROF  컬럼1     COLL_SET 컬럼7     17 0.531
#    CORP_PROF  컬럼5    LOAN_CTRT 컬럼8    232 0.527
#    CORP_PROF  컬럼1  ADM_DONG_CD 컬럼2     37 0.507
#       ZIP_CD  컬럼1    BRANCH_CD 컬럼1    570 0.504
#      KSIC_CD  컬럼1       ZIP_CD 컬럼1    606 0.503
#    LOAN_CTRT  컬럼6       CMN_CD 컬럼3     15 0.500
#    LOAN_CTRT  컬럼6       CMN_CD 컬럼4     12 0.500
#    CORP_PROF  컬럼5      KSIC_CD 컬럼3    248 0.495
#    LOAN_CTRT  컬럼6      PRD_MST 컬럼6     40 0.494
#    CORP_PROF  컬럼1      KSIC_CD 컬럼5    111 0.474
#    CORP_PROF  컬럼5    BRANCH_CD 컬럼1    480 0.425
#    CORP_PROF  컬럼5      KSIC_CD 컬럼1    448 0.372
#    LOAN_CTRT  컬럼6      PRD_MST 컬럼5    195 0.360
#      KSIC_CD  컬럼5  ADM_DONG_CD 컬럼4     42 0.341
#    CORP_PROF  컬럼1    BRANCH_CD 컬럼1    356 0.315
#    CORP_PROF  컬럼1    LOAN_CTRT 컬럼8    137 0.311
#    CORP_PROF  컬럼1      KSIC_CD 컬럼3    146 0.291
#  ADM_DONG_CD  컬럼2    BRANCH_CD 컬럼1     18 0.247
#  ADM_DONG_CD  컬럼4    BRANCH_CD 컬럼1     29 0.236
#    CORP_PROF  컬럼1    BRANCH_CD 컬럼5     37 0.234
#    CORP_PROF  컬럼1      KSIC_CD 컬럼1    276 0.229
#      KSIC_CD  컬럼7    BRANCH_CD 컬럼1     16 0.208
#      KSIC_CD  컬럼5  ADM_DONG_CD 컬럼2     13 0.178
#      KSIC_CD  컬럼5    BRANCH_CD 컬럼1     40 0.171
#    CORP_PROF  컬럼1       ZIP_CD 컬럼1   9766 0.140
#      KSIC_CD  컬럼3  ADM_DONG_CD 컬럼4     15 0.122
#      KSIC_CD  컬럼3    BRANCH_CD 컬럼1     59 0.118
#       ZIP_CD  컬럼4    BRANCH_CD 컬럼2    114 0.102

# %%
# 전체 테이블 EDA 실행
print("KB 금융 데이터 전체 EDA 분석 시작")
print("="*100)

if 'df_total' in locals() and len(df_total) > 0:
    print(f"총 테이블 수: {len(df_total)}")
    print(f"테이블 목록: {list(df_total.keys())}")
    print("\n각 테이블별 상세 분석을 시작합니다...")
    
    # 각 테이블별로 EDA 수행
    for table_name, df in df_total.items():
        perform_table_eda(df, table_name)
        
        # 메모리 절약을 위해 중간에 일시정지
        print("\n" + "-"*50 + " 다음 테이블로... " + "-"*50 + "\n")
        
else:
    print("df_total 딕셔너리가 정의되지 않았거나 비어있습니다.")
    print("먼저 앞의 데이터 로딩 셀을 실행해주세요.")
# Out:
# KB 금융 데이터 전체 EDA 분석 시작
# ====================================================================================================
# 총 테이블 수: 12
# 테이블 목록: ['CORP_PROF', 'CUST_MST', 'CORP_BIZ_MAP', 'LOAN_CTRT', 'PRD_MST', 'COLL_SET', 'CAI_TXN', 'KSIC_CD', 'ADM_DONG_CD', 'ZIP_CD', 'BRANCH_CD', 'CMN_CD']
#
# 각 테이블별 상세 분석을 시작합니다...
#
# ################################################################################
# 테이블: CORP_PROF
# ################################################################################
# 데이터 형태: (395108, 7)
# 컬럼 수: 7
# 행 수: 395,108
#
# ==================================================
# 수치형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 395,108
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 6,366,884.44
# 중앙값: 7,722,932.50
# 표준편차: 22,069,986.75
# 최솟값: 6.00
# 최댓값: 9,014,000,001.00
# 25% 분위수: 5,143,452.75
# 50% 분위수: 7,722,932.50
# 75% 분위수: 8,245,649.25
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 42,095
# 이상치 비율: 10.65%
# 이상치 범위: 490158.00 미만 또는 12898944.00 초과
#
# ==================================================
# 범주형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 395,108
# 고유값 개수: 87,586
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 에스****                         :    1,792 ( 0.45%)
#  2. 에스***                          :    1,635 ( 0.41%)
#  3. 에스*****                        :    1,593 ( 0.40%)
#  4. 제이****                         :    1,549 ( 0.39%)
#  5. 에이****                         :    1,537 ( 0.39%)
#  6. 제이*****                        :    1,363 ( 0.34%)
#  7. 에이***                          :    1,356 ( 0.34%)
#  8. 에이*****                        :    1,346 ( 0.34%)
#  9. 케이***                          :    1,261 ( 0.32%)
# 10. 제이***                          :    1,211 ( 0.31%)
# 11. 케이****                         :    1,210 ( 0.31%)
# 12. 에스******                       :    1,058 ( 0.27%)
# 13. 제이******                       :    1,004 ( 0.25%)
# 14. 케이*****                        :      989 ( 0.25%)
# 15. 에이******                       :      985 ( 0.25%)
# 16. 한국****                         :      968 ( 0.24%)
# 17. 아이***                          :      902 ( 0.23%)
# 18. 농업**********                   :      878 ( 0.22%)
# 19. 에스**                           :      857 ( 0.22%)
# 20. 케이**                           :      821 ( 0.21%)
#
# ... (총 87586개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 395,108
# 고유값 개수: 1,154
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. L68129                         :    9,477 ( 2.40%)
#  2. J58222                         :    7,654 ( 1.94%)
#  3. F41229                         :    7,355 ( 1.86%)
#  4. M71531                         :    6,990 ( 1.77%)
#  5. L68119                         :    6,552 ( 1.66%)
#  6. F42311                         :    6,470 ( 1.64%)
#  7. G46800                         :    6,335 ( 1.60%)
#  8. J58221                         :    5,979 ( 1.51%)
#  9. F42412                         :    5,777 ( 1.46%)
# 10. H52992                         :    4,165 ( 1.05%)
# 11. M71310                         :    4,148 ( 1.05%)
# 12. F42132                         :    4,134 ( 1.05%)
# 13. G46721                         :    3,747 ( 0.95%)
# 14. G47912                         :    3,704 ( 0.94%)
# 15. G46595                         :    3,628 ( 0.92%)
# 16. C26299                         :    3,515 ( 0.89%)
# 17. G46329                         :    3,233 ( 0.82%)
# 18. C30399                         :    3,191 ( 0.81%)
# 19. G46510                         :    3,179 ( 0.80%)
# 20. G46699                         :    3,168 ( 0.80%)
#
# ... (총 1154개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 수치형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 395,108
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 3,874,768,489.23
# 중앙값: 3,398,800,745.00
# 표준편차: 2,344,974,220.63
# 최솟값: 1,018,100,127.00
# 최댓값: 8,998,803,220.00
# 25% 분위수: 1,458,701,318.50
# 50% 분위수: 3,398,800,745.00
# 75% 분위수: 6,028,157,158.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 수치형 변수 분석: 컬럼 5
# ==================================================
# 총 데이터 개수: 395,108
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 24,469.70
# 중앙값: 17,128.00
# 표준편차: 18,418.19
# 최솟값: 0.00
# 최댓값: 99,999.00
# 25% 분위수: 8,505.00
# 50% 분위수: 17,128.00
# 75% 분위수: 40,113.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 46
# 이상치 비율: 0.01%
# 이상치 범위: -38907.00 미만 또는 87525.00 초과
#
# ==================================================
# 수치형 변수 분석: 컬럼 6
# ==================================================
# 총 데이터 개수: 395,108
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 1,515,145,691,022.59
# 중앙값: 1,348,110,046,388.50
# 표준편차: 457,578,930,942.87
# 최솟값: 1,011,110,565,642.00
# 최댓값: 2,850,710,010,320.00
# 25% 분위수: 1,101,117,479,092.00
# 50% 분위수: 1,348,110,046,388.50
# 75% 분위수: 1,801,110,648,262.75
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# 컬럼 7: 모든 값이 결측값입니다.
#
# ================================================================================
# CORP_PROF 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: CUST_MST
# ################################################################################
# 데이터 형태: (831796, 5)
# 컬럼 수: 5
# 행 수: 831,796
#
# ==================================================
# 수치형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 831,796
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 7,759,687,137.65
# 중앙값: 8,015,042,095.00
# 표준편차: 441,523,108.33
# 최솟값: 7,000,000,180.00
# 최댓값: 8,033,180,102.00
# 25% 분위수: 7,013,988,067.00
# 50% 분위수: 8,015,042,095.00
# 75% 분위수: 8,024,425,473.25
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 수치형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 831,796
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 721,780,999,879.56
# 중앙값: 8,298,103,331.50
# 표준편차: 817,896,688,048.55
# 최솟값: 1,018,100,127.00
# 최댓값: 2,850,710,010,320.00
# 25% 분위수: 3,268,700,111.25
# 50% 분위수: 8,298,103,331.50
# 75% 분위수: 1,345,110,001,634.50
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 831,796
# 고유값 개수: 2
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 2개 카테고리:
# ------------------------------
#  1. 2                              :  436,688 (52.50%)
#  2. 7                              :  395,108 (47.50%)
#
# ==================================================
# 범주형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 831,796
# 고유값 개수: 2
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 2개 카테고리:
# ------------------------------
#  1. 4                              :  436,688 (52.50%)
#  2. 3                              :  395,108 (47.50%)
#
# 컬럼 5: 모든 값이 결측값입니다.
#
# ================================================================================
# CUST_MST 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: CORP_BIZ_MAP
# ################################################################################
# 데이터 형태: (436688, 3)
# 컬럼 수: 3
# 행 수: 436,688
#
# ==================================================
# 수치형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 436,688
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 7,764,291,226.91
# 중앙값: 8,016,182,150.50
# 표준편차: 439,353,843.20
# 최솟값: 7,000,000,180.00
# 최댓값: 8,033,180,102.00
# 25% 분위수: 7,020,334,992.50
# 50% 분위수: 8,016,182,150.50
# 75% 분위수: 8,025,094,440.25
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 수치형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 436,688
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 7,764,291,226.91
# 중앙값: 8,016,182,150.50
# 표준편차: 439,353,843.20
# 최솟값: 7,000,000,180.00
# 최댓값: 8,033,180,102.00
# 25% 분위수: 7,020,334,992.50
# 50% 분위수: 8,016,182,150.50
# 75% 분위수: 8,025,094,440.25
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# 컬럼 3: 모든 값이 결측값입니다.
#
# ================================================================================
# CORP_BIZ_MAP 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: LOAN_CTRT
# ################################################################################
# 데이터 형태: (25203, 14)
# 컬럼 수: 14
# 행 수: 25,203
#
# ==================================================
# 수치형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 25,203
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 149,848,674,927,470.44
# 중앙값: 167,974,813,290,957.00
# 표준편차: 83,682,449,956,366.48
# 최솟값: 454,813,538,673.00
# 최댓값: 297,951,900,086,913.00
# 25% 분위수: 75,544,812,833,448.00
# 50% 분위수: 167,974,813,290,957.00
# 75% 분위수: 222,964,812,789,039.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 1
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 1개 카테고리:
# ------------------------------
#  1. 0                              :   25,203 (100.00%)
#
# ==================================================
# 수치형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 25,203
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 7,586,939,241.70
# 중앙값: 8,002,739,517.00
# 표준편차: 497,283,595.31
# 최솟값: 7,000,001,863.00
# 최댓값: 8,032,950,026.00
# 25% 분위수: 7,008,020,145.00
# 50% 분위수: 8,002,739,517.00
# 75% 분위수: 8,015,669,560.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 1
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 1개 카테고리:
# ------------------------------
#  1. 1                              :   25,203 (100.00%)
#
# ==================================================
# 범주형 변수 분석: 컬럼 5
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 277
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 2532P0200001                   :    8,068 (32.01%)
#  2. 2534P0500001                   :    5,837 (23.16%)
#  3. 2532P3300001                   :    1,248 ( 4.95%)
#  4. 2532P0200030                   :      956 ( 3.79%)
#  5. 2532P0200059                   :      792 ( 3.14%)
#  6. 2534P0500034                   :      747 ( 2.96%)
#  7. 2534P3300001                   :      600 ( 2.38%)
#  8. 2534P0500021                   :      382 ( 1.52%)
#  9. 2542A2200006                   :      357 ( 1.42%)
# 10. 2542A2700001                   :      215 ( 0.85%)
# 11. 2532P2800001                   :      215 ( 0.85%)
# 12. 2542A2800001                   :      213 ( 0.85%)
# 13. 2549P2500001                   :      212 ( 0.84%)
# 14. 2534P2800001                   :      210 ( 0.83%)
# 15. 2533D0500001                   :      194 ( 0.77%)
# 16. 2533D7600001                   :      187 ( 0.74%)
# 17. 2534P0500111                   :      185 ( 0.73%)
# 18. 2548P0600001                   :      180 ( 0.71%)
# 19. 2533D1600001                   :      180 ( 0.71%)
# 20. 2534P0500031                   :      175 ( 0.69%)
#
# ... (총 277개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 6
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 2,321
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 20240816                       :      142 ( 0.56%)
#  2. 20250530                       :      134 ( 0.53%)
#  3. 20240329                       :      133 ( 0.53%)
#  4. 20250331                       :      130 ( 0.52%)
#  5. 20240731                       :      127 ( 0.50%)
#  6. 20250326                       :      127 ( 0.50%)
#  7. 20240628                       :      124 ( 0.49%)
#  8. 20240426                       :      124 ( 0.49%)
#  9. 20251031                       :      121 ( 0.48%)
# 10. 20250328                       :      118 ( 0.47%)
# 11. 20250228                       :      114 ( 0.45%)
# 12. 20250430                       :      107 ( 0.42%)
# 13. 20250926                       :      102 ( 0.40%)
# 14. 20240229                       :       93 ( 0.37%)
# 15. 20250930                       :       92 ( 0.37%)
# 16. 20250829                       :       90 ( 0.36%)
# 17. 20250630                       :       86 ( 0.34%)
# 18. 20240830                       :       85 ( 0.34%)
# 19. 20250627                       :       84 ( 0.33%)
# 20. 20240531                       :       84 ( 0.33%)
#
# ... (총 2321개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 7
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 1,805
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 20260327                       :      218 ( 0.86%)
#  2. 20260228                       :      202 ( 0.80%)
#  3. 20260430                       :      194 ( 0.77%)
#  4. 20260331                       :      190 ( 0.75%)
#  5. 20260930                       :      182 ( 0.72%)
#  6. 20260731                       :      182 ( 0.72%)
#  7. 20260328                       :      177 ( 0.70%)
#  8. 20260630                       :      163 ( 0.65%)
#  9. 20260530                       :      163 ( 0.65%)
# 10. 20260627                       :      142 ( 0.56%)
# 11. 20260320                       :      132 ( 0.52%)
# 12. 20260814                       :      131 ( 0.52%)
# 13. 20260227                       :      129 ( 0.51%)
# 14. 20260522                       :      123 ( 0.49%)
# 15. 20260628                       :      122 ( 0.48%)
# 16. 20260612                       :      118 ( 0.47%)
# 17. 20260730                       :      118 ( 0.47%)
# 18. 20260424                       :      116 ( 0.46%)
# 19. 20261030                       :      116 ( 0.46%)
# 20. 20260429                       :      116 ( 0.46%)
#
# ... (총 1805개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 8
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 440
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 7933                           :      328 ( 1.30%)
#  2. 8398                           :      291 ( 1.15%)
#  3. 5997                           :      287 ( 1.14%)
#  4. 6556                           :      212 ( 0.84%)
#  5. 9290                           :      211 ( 0.84%)
#  6. 2932                           :      201 ( 0.80%)
#  7. 7661                           :      196 ( 0.78%)
#  8. 6752                           :      193 ( 0.77%)
#  9. 6749                           :      178 ( 0.71%)
# 10. 8424                           :      173 ( 0.69%)
# 11. 7726                           :      166 ( 0.66%)
# 12. 7713                           :      166 ( 0.66%)
# 13. 6802                           :      164 ( 0.65%)
# 14. 1739                           :      163 ( 0.65%)
# 15. 688                            :      163 ( 0.65%)
# 16. 8101                           :      162 ( 0.64%)
# 17. 4217                           :      161 ( 0.64%)
# 18. 6604                           :      160 ( 0.63%)
# 19. 5465                           :      155 ( 0.62%)
# 20. 7968                           :      155 ( 0.62%)
#
# ... (총 440개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 9
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 2
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 2개 카테고리:
# ------------------------------
#  1. KRW                            :   25,192 (99.96%)
#  2. USD                            :       11 ( 0.04%)
#
# ==================================================
# 수치형 변수 분석: 컬럼 10
# ==================================================
# 총 데이터 개수: 25,203
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 2,891,482,958.38
# 중앙값: 666,000,000.00
# 표준편차: 16,545,633,148.31
# 최솟값: 0.00
# 최댓값: 987,400,000,000.00
# 25% 분위수: 303,000,000.00
# 50% 분위수: 666,000,000.00
# 75% 분위수: 1,775,500,000.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 3,214
# 이상치 비율: 12.75%
# 이상치 범위: -1905750000.00 미만 또는 3984250000.00 초과
#
# ==================================================
# 범주형 변수 분석: 컬럼 11
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 4
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 4개 카테고리:
# ------------------------------
#  1. 1                              :   21,685 (86.04%)
#  2. 2                              :    3,190 (12.66%)
#  3. 0                              :      282 ( 1.12%)
#  4. 3                              :       46 ( 0.18%)
#
# ==================================================
# 범주형 변수 분석: 컬럼 12
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 4
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 4개 카테고리:
# ------------------------------
#  1. 0                              :   23,594 (93.62%)
#  2. 3                              :    1,327 ( 5.27%)
#  3. 1                              :      216 ( 0.86%)
#  4. 2                              :       66 ( 0.26%)
#
# ==================================================
# 수치형 변수 분석: 컬럼 13
# ==================================================
# 총 데이터 개수: 1,327
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 140,193,427,564,295.09
# 중앙값: 148,080,303,706,614.00
# 표준편차: 85,158,954,760,405.67
# 최솟값: 18,054,008,442.00
# 최댓값: 297,930,303,720,741.00
# 25% 분위수: 65,325,307,993,111.50
# 50% 분위수: 148,080,303,706,614.00
# 75% 분위수: 210,155,708,164,518.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# 컬럼 14: 모든 값이 결측값입니다.
#
# ================================================================================
# LOAN_CTRT 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: PRD_MST
# ################################################################################
# 데이터 형태: (1342, 7)
# 컬럼 수: 7
# 행 수: 1,342
#
# ==================================================
# 범주형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 1,342
# 고유값 개수: 1
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 1개 카테고리:
# ------------------------------
#  1. 1                              :    1,342 (100.00%)
#
# ==================================================
# 범주형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 1,342
# 고유값 개수: 1,342
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 250110100001                   :        1 ( 0.07%)
#  2. 2545M5000003                   :        1 ( 0.07%)
#  3. 2545M5000001                   :        1 ( 0.07%)
#  4. 2544M5400001                   :        1 ( 0.07%)
#  5. 2544M5000001                   :        1 ( 0.07%)
#  6. 2544M4900001                   :        1 ( 0.07%)
#  7. 2544M4800001                   :        1 ( 0.07%)
#  8. 2544M4700001                   :        1 ( 0.07%)
#  9. 2544M4600001                   :        1 ( 0.07%)
# 10. 2544M4500001                   :        1 ( 0.07%)
# 11. 2544M4400001                   :        1 ( 0.07%)
# 12. 2544M4300002                   :        1 ( 0.07%)
# 13. 2544M4300001                   :        1 ( 0.07%)
# 14. 2544H3900001                   :        1 ( 0.07%)
# 15. 2544H3800001                   :        1 ( 0.07%)
# 16. 2544H3700001                   :        1 ( 0.07%)
# 17. 2544H3600001                   :        1 ( 0.07%)
# 18. 2543M9500001                   :        1 ( 0.07%)
# 19. 2543M5000001                   :        1 ( 0.07%)
# 20. 2545M5000002                   :        1 ( 0.07%)
#
# ... (총 1342개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 1,342
# 고유값 개수: 814
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 투자금융 외국기업역외외화대출금               :       18 ( 1.34%)
#  2. 투자금융 대외기타외화대출금                 :       18 ( 1.34%)
#  3. 투자금융 국민비거주자역외와화대출금             :       18 ( 1.34%)
#  4. 투자금융 해외지사역외외화대출금               :       18 ( 1.34%)
#  5. 투자금융 해외현지법인 역외 외화대출금           :       18 ( 1.34%)
#  6. 투자금융 해외투자금융역외외화대출금             :       18 ( 1.34%)
#  7. 투자금융 해외은행 역외 외화대출금             :       18 ( 1.34%)
#  8. 투자금융 기타기관역외외화대출금               :       18 ( 1.34%)
#  9. 투자금융 대내기타외화대출금                 :       18 ( 1.34%)
# 10. 투자금융 일반운전일시상환자금                :       12 ( 0.89%)
# 11. 투자금융 일반시설일시상환자금                :       10 ( 0.75%)
# 12. 투자금융 시설자금(후분양프로젝트 주택자금)        :        9 ( 0.67%)
# 13. 투자금융 CP매입자금                    :        9 ( 0.67%)
# 14. 투자금융 일반시설분할상환자금                :        9 ( 0.67%)
# 15. 투자금융 일반운전분할상환자금                :        9 ( 0.67%)
# 16. 투자금융 운전자금(후분양프로젝트 주택자금)        :        9 ( 0.67%)
# 17. 투자금융외평기금외화대출_해외수주지원            :        6 ( 0.45%)
# 18. 건설업자운전자금대출                     :        5 ( 0.37%)
# 19. 기타원화지급보증대지급금                   :        5 ( 0.37%)
# 20. 투자금융외평기금외화대출_대기업               :        4 ( 0.30%)
#
# ... (총 814개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 1,342
# 고유값 개수: 1
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 1개 카테고리:
# ------------------------------
#  1. 1                              :    1,342 (100.00%)
#
# ==================================================
# 수치형 변수 분석: 컬럼 5
# ==================================================
# 총 데이터 개수: 1,342
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 19,869,999.22
# 중앙값: 20,100,930.00
# 표준편차: 474,288.83
# 최솟값: 19,000,101.00
# 최댓값: 20,251,117.00
# 25% 분위수: 19,940,392.00
# 50% 분위수: 20,100,930.00
# 75% 분위수: 20,180,325.75
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 300
# 이상치 비율: 22.35%
# 이상치 범위: 19580491.38 미만 또는 20540226.38 초과
#
# ==================================================
# 범주형 변수 분석: 컬럼 6
# ==================================================
# 총 데이터 개수: 1,342
# 고유값 개수: 81
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 99991231                       :      932 (69.45%)
#  2. 20211116                       :       59 ( 4.40%)
#  3. 20221225                       :       29 ( 2.16%)
#  4. 20071231                       :       28 ( 2.09%)
#  5. 20150227                       :       27 ( 2.01%)
#  6. 20180112                       :       24 ( 1.79%)
#  7. 20250317                       :       19 ( 1.42%)
#  8. 20230323                       :       17 ( 1.27%)
#  9. 20080520                       :       15 ( 1.12%)
# 10. 20210323                       :       13 ( 0.97%)
# 11. 20220811                       :       12 ( 0.89%)
# 12. 20250629                       :       10 ( 0.75%)
# 13. 20001231                       :        9 ( 0.67%)
# 14. 20201231                       :        7 ( 0.52%)
# 15. 20180115                       :        7 ( 0.52%)
# 16. 20101102                       :        7 ( 0.52%)
# 17. 20200528                       :        6 ( 0.45%)
# 18. 20210115                       :        6 ( 0.45%)
# 19. 20151231                       :        5 ( 0.37%)
# 20. 20250424                       :        5 ( 0.37%)
#
# ... (총 81개 카테고리 중 상위 20개만 표시)
#
# 컬럼 7: 모든 값이 결측값입니다.
#
# ================================================================================
# PRD_MST 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: COLL_SET
# ################################################################################
# 데이터 형태: (25203, 8)
# 컬럼 수: 8
# 행 수: 25,203
#
# ==================================================
# 수치형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 25,203
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 149,520,718,610,458.69
# 중앙값: 167,190,312,386,649.00
# 표준편차: 83,684,408,002,402.44
# 최솟값: 18,054,008,442.00
# 최댓값: 297,934,803,583,746.00
# 25% 분위수: 75,154,813,148,074.50
# 50% 분위수: 167,190,312,386,649.00
# 75% 분위수: 222,964,812,680,284.50
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 수치형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 25,203
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 2,891,482,958.38
# 중앙값: 666,000,000.00
# 표준편차: 16,545,633,148.31
# 최솟값: 0.00
# 최댓값: 987,400,000,000.00
# 25% 분위수: 303,000,000.00
# 50% 분위수: 666,000,000.00
# 75% 분위수: 1,775,500,000.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 3,214
# 이상치 비율: 12.75%
# 이상치 범위: -1905750000.00 미만 또는 3984250000.00 초과
#
# ==================================================
# 수치형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 25,203
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 8,964,822,362.42
# 중앙값: 2,039,000,000.00
# 표준편차: 56,080,371,991.90
# 최솟값: 15,000,000.00
# 최댓값: 1,914,527,000,000.00
# 25% 분위수: 851,000,000.00
# 50% 분위수: 2,039,000,000.00
# 75% 분위수: 5,266,000,000.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 3,085
# 이상치 비율: 12.24%
# 이상치 범위: -5771500000.00 미만 또는 11888500000.00 초과
#
# ==================================================
# 수치형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 25,203
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 45.21
# 중앙값: 42.29
# 표준편차: 36.85
# 최솟값: 0.00
# 최댓값: 2,062.70
# 25% 분위수: 21.41
# 50% 분위수: 42.29
# 75% 분위수: 63.38
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 252
# 이상치 비율: 1.00%
# 이상치 범위: -41.54 미만 또는 126.32 초과
#
# ==================================================
# 수치형 변수 분석: 컬럼 5
# ==================================================
# 총 데이터 개수: 25,203
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 191,824,622.79
# 중앙값: 203,185,441.00
# 표준편차: 36,924,249.00
# 최솟값: 41,119.00
# 최댓값: 205,495,880.00
# 25% 분위수: 201,937,009.00
# 50% 분위수: 203,185,441.00
# 75% 분위수: 204,135,576.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 2,331
# 이상치 비율: 9.25%
# 이상치 범위: 198639158.50 미만 또는 207433426.50 초과
#
# ==================================================
# 수치형 변수 분석: 컬럼 6
# ==================================================
# 총 데이터 개수: 25,203
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 3,235,840,998.88
# 중앙값: 4,113,511,400.00
# 표준편차: 1,370,112,736.07
# 최솟값: 1,111,010,100.00
# 최댓값: 5,280,041,022.00
# 25% 분위수: 2,620,011,500.00
# 50% 분위수: 4,113,511,400.00
# 75% 분위수: 4,159,037,023.50
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 7
# ==================================================
# 총 데이터 개수: 25,203
# 고유값 개수: 32
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 154                            :    7,747 (30.74%)
#  2. 151                            :    4,415 (17.52%)
#  3. 121                            :    4,011 (15.91%)
#  4. 155                            :    2,355 ( 9.34%)
#  5. 160                            :    1,023 ( 4.06%)
#  6. 111                            :      953 ( 3.78%)
#  7. 157                            :      807 ( 3.20%)
#  8. 152                            :      722 ( 2.86%)
#  9. 130                            :      453 ( 1.80%)
# 10. 113                            :      421 ( 1.67%)
# 11. 159                            :      315 ( 1.25%)
# 12. 114                            :      292 ( 1.16%)
# 13. 120                            :      216 ( 0.86%)
# 14. 134                            :      157 ( 0.62%)
# 15. 135                            :      156 ( 0.62%)
# 16. 122                            :      146 ( 0.58%)
# 17. 127                            :      126 ( 0.50%)
# 18. 133                            :      125 ( 0.50%)
# 19. 136                            :      116 ( 0.46%)
# 20. 156                            :      115 ( 0.46%)
#
# ... (총 32개 카테고리 중 상위 20개만 표시)
#
# 컬럼 8: 모든 값이 결측값입니다.
#
# ================================================================================
# COLL_SET 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: CAI_TXN
# ################################################################################
# 데이터 형태: (254928, 4)
# 컬럼 수: 4
# 행 수: 254,928
#
# ==================================================
# 수치형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 254,928
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 2,940,173,600.30
# 중앙값: 2,028,114,695.00
# 표준편차: 2,106,205,759.59
# 최솟값: 1,018,100,452.00
# 최댓값: 8,998,803,050.00
# 25% 분위수: 1,288,147,957.00
# 50% 분위수: 2,028,114,695.00
# 75% 분위수: 4,288,602,845.50
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 1,149
# 이상치 비율: 0.45%
# 이상치 범위: -3212534375.75 미만 또는 8789285178.25 초과
#
# ==================================================
# 수치형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 254,928
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 3,175,446,703.87
# 중앙값: 2,118,708,904.00
# 표준편차: 2,347,849,329.34
# 최솟값: 1,018,100,452.00
# 최댓값: 8,998,803,079.00
# 25% 분위수: 1,228,183,757.75
# 50% 분위수: 2,118,708,904.00
# 75% 분위수: 5,068,104,221.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 수치형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 254,928
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 167,024,898.91
# 중앙값: 8,280,000.00
# 표준편차: 3,613,191,296.34
# 최솟값: -896,750,000.00
# 최댓값: 1,148,701,380,000.00
# 25% 분위수: 770,000.00
# 50% 분위수: 8,280,000.00
# 75% 분위수: 48,262,500.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 36,883
# 이상치 비율: 14.47%
# 이상치 범위: -70468750.00 미만 또는 119501250.00 초과
#
# 컬럼 4: 모든 값이 결측값입니다.
#
# ================================================================================
# CAI_TXN 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: KSIC_CD
# ################################################################################
# 데이터 형태: (1205, 11)
# 컬럼 수: 11
# 행 수: 1,205
#
# ==================================================
# 수치형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 1,205
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 44,706.76
# 중앙값: 45,212.00
# 표준편차: 25,723.89
# 최솟값: 1,110.00
# 최댓값: 99,009.00
# 25% 분위수: 24,219.00
# 50% 분위수: 45,212.00
# 75% 분위수: 63,910.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 1,205
# 고유값 개수: 1,205
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 곡물 및 기타 식량작물 재배업               :        1 ( 0.08%)
#  2. 일반 창고업                         :        1 ( 0.08%)
#  3. 항공 여객 운송업                      :        1 ( 0.08%)
#  4. 기타 내륙 수상 여객 및 화물 운송업           :        1 ( 0.08%)
#  5. 항만 내 여객 운송업                    :        1 ( 0.08%)
#  6. 기타 해상 운송업                      :        1 ( 0.08%)
#  7. 내항 화물 운송업                      :        1 ( 0.08%)
#  8. 내항 여객 운송업                      :        1 ( 0.08%)
#  9. 외항 화물 운송업                      :        1 ( 0.08%)
# 10. 외항 여객 운송업                      :        1 ( 0.08%)
# 11. 파이프라인 운송업                      :        1 ( 0.08%)
# 12. 늘찬 배달업                         :        1 ( 0.08%)
# 13. 택배업                            :        1 ( 0.08%)
# 14. 기타 도로화물 운송업                    :        1 ( 0.08%)
# 15. 개인 화물자동차 운송업                   :        1 ( 0.08%)
# 16. 일반 화물자동차 운송업                   :        1 ( 0.08%)
# 17. 기타 부정기 여객 육상 운송업               :        1 ( 0.08%)
# 18. 항공 화물 운송업                      :        1 ( 0.08%)
# 19. 냉장 및 냉동 창고업                    :        1 ( 0.08%)
# 20. 전세버스 운송업                       :        1 ( 0.08%)
#
# ... (총 1205개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 수치형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 1,205
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 4,470.39
# 중앙값: 4,521.00
# 표준편차: 2,572.39
# 최솟값: 111.00
# 최댓값: 9,900.00
# 25% 분위수: 2,421.00
# 50% 분위수: 4,521.00
# 75% 분위수: 6,391.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 1,205
# 고유값 개수: 501
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 상품 중개업                         :        8 ( 0.66%)
#  2. 생활용 섬유제품, 의복, 의복 액세서리 및 모피제품 도 :        8 ( 0.66%)
#  3. 기타 식료품 제조업                     :        8 ( 0.66%)
#  4. 의복 소매업                         :        8 ( 0.66%)
#  5. 토목 시설물 건설업                     :        7 ( 0.58%)
#  6. 콘크리트, 레미콘 및 기타 시멘트, 플라스터 제품 제조 :        7 ( 0.58%)
#  7. 펄프, 종이 및 판지 제조업                :        7 ( 0.58%)
#  8. 기타 의료용 기기 제조업                  :        7 ( 0.58%)
#  9. 측정, 시험, 항해, 제어 및 기타 정밀 기기 제조업  :        7 ( 0.58%)
# 10. 기타 기계 및 장비 도매업                 :        7 ( 0.58%)
# 11. 기타 스포츠시설 운영업                   :        7 ( 0.58%)
# 12. 냉각, 공기 조화, 여과, 증류 및 가스 발생기 제조업 :        7 ( 0.58%)
# 13. 기타 시설물 축조 관련 전문 공사업            :        7 ( 0.58%)
# 14. 가공식품 도매업                       :        7 ( 0.58%)
# 15. 육상 운송 지원 서비스업                  :        6 ( 0.50%)
# 16. 사법 및 공공 질서 행정                  :        6 ( 0.50%)
# 17. 그 외 기타 비금속 광물제품 제조업            :        6 ( 0.50%)
# 18. 산업용 농ㆍ축산물 및 동ㆍ식물 도매업           :        6 ( 0.50%)
# 19. 그 외 기타 분류 안된 개인 서비스업           :        6 ( 0.50%)
# 20. 일반 및 생활 숙박시설 운영업               :        6 ( 0.50%)
#
# ... (총 501개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 수치형 변수 분석: 컬럼 5
# ==================================================
# 총 데이터 개수: 1,205
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 446.77
# 중앙값: 452.00
# 표준편차: 257.24
# 최솟값: 11.00
# 최댓값: 990.00
# 25% 분위수: 242.00
# 50% 분위수: 452.00
# 75% 분위수: 639.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 6
# ==================================================
# 총 데이터 개수: 1,205
# 고유값 개수: 234
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 생활용품 도매업                       :       29 ( 2.41%)
#  2. 일반 목적용 기계 제조업                  :       25 ( 2.07%)
#  3. 기타 금속 가공제품 제조업                 :       23 ( 1.91%)
#  4. 특수 목적용 기계 제조업                  :       19 ( 1.58%)
#  5. 기타 운송관련 서비스업                   :       17 ( 1.41%)
#  6. 플라스틱 제품 제조업                    :       17 ( 1.41%)
#  7. 기타 상품 전문 소매업                   :       16 ( 1.33%)
#  8. 음ㆍ식료품 및 담배 도매업                 :       16 ( 1.33%)
#  9. 음식점업                           :       16 ( 1.33%)
# 10. 기타 교육기관                        :       15 ( 1.24%)
# 11. 기반조성 및 시설물 축조관련 전문공사업          :       14 ( 1.16%)
# 12. 기계장비 및 관련 물품 도매업               :       14 ( 1.16%)
# 13. 기타 식품 제조업                      :       14 ( 1.16%)
# 14. 스포츠 서비스업                       :       14 ( 1.16%)
# 15. 기타 전문 도매업                      :       14 ( 1.16%)
# 16. 유원지 및 기타 오락관련 서비스업             :       14 ( 1.16%)
# 17. 기타 화학제품 제조업                    :       13 ( 1.08%)
# 18. 섬유, 의복, 신발 및 가죽제품 소매업          :       13 ( 1.08%)
# 19. 1차 철강 제조업                      :       12 ( 1.00%)
# 20. 음ㆍ식료품 및 담배 소매업                 :       12 ( 1.00%)
#
# ... (총 234개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 7
# ==================================================
# 총 데이터 개수: 1,205
# 고유값 개수: 77
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 46                             :       96 ( 7.97%)
#  2. 47                             :       81 ( 6.72%)
#  3. 10                             :       45 ( 3.73%)
#  4. 29                             :       44 ( 3.65%)
#  5. 23                             :       34 ( 2.82%)
#  6. 85                             :       33 ( 2.74%)
#  7. 25                             :       33 ( 2.74%)
#  8. 42                             :       32 ( 2.66%)
#  9. 20                             :       31 ( 2.57%)
# 10. 26                             :       30 ( 2.49%)
# 11. 13                             :       28 ( 2.32%)
# 12. 84                             :       28 ( 2.32%)
# 13. 91                             :       28 ( 2.32%)
# 14. 28                             :       26 ( 2.16%)
# 15. 24                             :       24 ( 1.99%)
# 16. 52                             :       22 ( 1.83%)
# 17. 22                             :       22 ( 1.83%)
# 18. 56                             :       22 ( 1.83%)
# 19. 1                              :       21 ( 1.74%)
# 20. 33                             :       20 ( 1.66%)
#
# ... (총 77개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 8
# ==================================================
# 총 데이터 개수: 1,205
# 고유값 개수: 77
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 도매 및 상품 중개업                    :       96 ( 7.97%)
#  2. 소매업; 자동차 제외                    :       81 ( 6.72%)
#  3. 식료품 제조업                        :       45 ( 3.73%)
#  4. 기타 기계 및 장비 제조업                 :       44 ( 3.65%)
#  5. 비금속 광물제품 제조업                   :       34 ( 2.82%)
#  6. 교육 서비스업                        :       33 ( 2.74%)
#  7. 금속 가공제품 제조업; 기계 및 가구 제외        :       33 ( 2.74%)
#  8. 전문직별 공사업                       :       32 ( 2.66%)
#  9. 화학 물질 및 화학제품 제조업; 의약품 제외       :       31 ( 2.57%)
# 10. 전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  :       30 ( 2.49%)
# 11. 섬유제품 제조업; 의복 제외                :       28 ( 2.32%)
# 12. 공공 행정, 국방 및 사회보장 행정            :       28 ( 2.32%)
# 13. 스포츠 및 오락관련 서비스업                :       28 ( 2.32%)
# 14. 전기장비 제조업                       :       26 ( 2.16%)
# 15. 1차 금속 제조업                      :       24 ( 1.99%)
# 16. 창고 및 운송관련 서비스업                 :       22 ( 1.83%)
# 17. 고무 및 플라스틱제품 제조업                :       22 ( 1.83%)
# 18. 음식점 및 주점업                      :       22 ( 1.83%)
# 19. 농업                             :       21 ( 1.74%)
# 20. 기타 제품 제조업                      :       20 ( 1.66%)
#
# ... (총 77개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 9
# ==================================================
# 총 데이터 개수: 1,205
# 고유값 개수: 21
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. C                              :      480 (39.83%)
#  2. G                              :      186 (15.44%)
#  3. M                              :       50 ( 4.15%)
#  4. H                              :       47 ( 3.90%)
#  5. F                              :       46 ( 3.82%)
#  6. J                              :       45 ( 3.73%)
#  7. R                              :       43 ( 3.57%)
#  8. S                              :       41 ( 3.40%)
#  9. A                              :       33 ( 2.74%)
# 10. P                              :       33 ( 2.74%)
# 11. N                              :       32 ( 2.66%)
# 12. I                              :       30 ( 2.49%)
# 13. K                              :       29 ( 2.41%)
# 14. O                              :       28 ( 2.32%)
# 15. Q                              :       25 ( 2.07%)
# 16. E                              :       19 ( 1.58%)
# 17. L                              :       12 ( 1.00%)
# 18. B                              :       11 ( 0.91%)
# 19. D                              :       10 ( 0.83%)
# 20. T                              :        3 ( 0.25%)
#
# ... (총 21개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 10
# ==================================================
# 총 데이터 개수: 1,205
# 고유값 개수: 21
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 제조업(10~34)                     :      480 (39.83%)
#  2. 도매 및 소매업(45~47)                :      186 (15.44%)
#  3. 전문, 과학 및 기술 서비스업(70~73)        :       50 ( 4.15%)
#  4. 운수 및 창고업(49~52)                :       47 ( 3.90%)
#  5. 건설업(41~42)                     :       46 ( 3.82%)
#  6. 정보통신업(58~63)                   :       45 ( 3.73%)
#  7. 예술, 스포츠 및 여가관련 서비스업(90~91)     :       43 ( 3.57%)
#  8. 협회 및 단체, 수리 및 기타 개인 서비스업(94~96 :       41 ( 3.40%)
#  9. 농업, 임업 및 어업(01~03)             :       33 ( 2.74%)
# 10. 교육 서비스업(85)                    :       33 ( 2.74%)
# 11. 사업시설 관리, 사업 지원 및 임대 서비스업(74~76 :       32 ( 2.66%)
# 12. 숙박 및 음식점업(55~56)               :       30 ( 2.49%)
# 13. 금융 및 보험업(64~66)                :       29 ( 2.41%)
# 14. 공공 행정, 국방 및 사회보장 행정(84)        :       28 ( 2.32%)
# 15. 보건업 및 사회복지 서비스업(86~87)         :       25 ( 2.07%)
# 16. 수도, 하수 및 폐기물 처리, 원료 재생업(36~39) :       19 ( 1.58%)
# 17. 부동산업(68)                       :       12 ( 1.00%)
# 18. 광업(05~08)                      :       11 ( 0.91%)
# 19. 전기, 가스, 증기 및 공기 조절 공급업(35)     :       10 ( 0.83%)
# 20. 가구 내 고용활동 및 달리 분류되지 않은 자가 소비 생 :        3 ( 0.25%)
#
# ... (총 21개 카테고리 중 상위 20개만 표시)
#
# 컬럼 11: 모든 값이 결측값입니다.
#
# ================================================================================
# KSIC_CD 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: ADM_DONG_CD
# ################################################################################
# 데이터 형태: (25071, 12)
# 컬럼 수: 12
# 행 수: 25,071
#
# ==================================================
# 범주형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 25,071
# 고유값 개수: 20
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 47                             :    3,507 (13.99%)
#  2. 46                             :    3,043 (12.14%)
#  3. 41                             :    2,537 (10.12%)
#  4. 48                             :    2,433 ( 9.70%)
#  5. 44                             :    2,289 ( 9.13%)
#  6. 43                             :    1,943 ( 7.75%)
#  7. 52                             :    1,901 ( 7.58%)
#  8. 45                             :    1,901 ( 7.58%)
#  9. 42                             :    1,514 ( 6.04%)
# 10. 51                             :    1,479 ( 5.90%)
# 11. 11                             :      493 ( 1.97%)
# 12. 27                             :      445 ( 1.77%)
# 13. 28                             :      297 ( 1.18%)
# 14. 26                             :      296 ( 1.18%)
# 15. 31                             :      225 ( 0.90%)
# 16. 50                             :      216 ( 0.86%)
# 17. 29                             :      208 ( 0.83%)
# 18. 30                             :      183 ( 0.73%)
# 19. 36                             :      160 ( 0.64%)
# 20. 99                             :        1 ( 0.00%)
#
# ==================================================
# 범주형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 25,071
# 고유값 개수: 73
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 11                             :    1,796 ( 7.16%)
#  2. 71                             :    1,301 ( 5.19%)
#  3. 13                             :    1,299 ( 5.18%)
#  4. 72                             :    1,125 ( 4.49%)
#  5. 73                             :    1,030 ( 4.11%)
#  6. 15                             :    1,015 ( 4.05%)
#  7. 77                             :    1,012 ( 4.04%)
#  8. 80                             :      920 ( 3.67%)
#  9. 23                             :      863 ( 3.44%)
# 10. 79                             :      862 ( 3.44%)
# 11. 17                             :      840 ( 3.35%)
# 12. 82                             :      805 ( 3.21%)
# 13. 19                             :      657 ( 2.62%)
# 14. 75                             :      652 ( 2.60%)
# 15. 21                             :      647 ( 2.58%)
# 16. 83                             :      629 ( 2.51%)
# 17. 76                             :      623 ( 2.48%)
# 18. 14                             :      552 ( 2.20%)
# 19. 18                             :      500 ( 1.99%)
# 20. 74                             :      499 ( 1.99%)
#
# ... (총 73개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 25,071
# 고유값 개수: 9
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 9개 카테고리:
# ------------------------------
#  1. 0                              :   23,147 (92.33%)
#  2. 1                              :      737 ( 2.94%)
#  3. 3                              :      500 ( 1.99%)
#  4. 5                              :      374 ( 1.49%)
#  5. 4                              :      106 ( 0.42%)
#  6. 9                              :       76 ( 0.30%)
#  7. 7                              :       63 ( 0.25%)
#  8. 2                              :       59 ( 0.24%)
#  9. 6                              :        9 ( 0.04%)
#
# ==================================================
# 범주형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 25,071
# 고유값 개수: 123
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 250                            :    2,492 ( 9.94%)
#  2. 310                            :    1,929 ( 7.69%)
#  3. 320                            :    1,815 ( 7.24%)
#  4. 340                            :    1,784 ( 7.12%)
#  5. 330                            :    1,776 ( 7.08%)
#  6. 350                            :    1,686 ( 6.72%)
#  7. 360                            :    1,653 ( 6.59%)
#  8. 370                            :    1,347 ( 5.37%)
#  9. 380                            :    1,115 ( 4.45%)
# 10. 390                            :      939 ( 3.75%)
# 11. 253                            :      858 ( 3.42%)
# 12. 400                            :      749 ( 2.99%)
# 13. 410                            :      479 ( 1.91%)
# 14. 420                            :      372 ( 1.48%)
# 15. 0                              :      323 ( 1.29%)
# 16. 256                            :      301 ( 1.20%)
# 17. 430                            :      260 ( 1.04%)
# 18. 259                            :      197 ( 0.79%)
# 19. 102                            :      180 ( 0.72%)
# 20. 101                            :      180 ( 0.72%)
#
# ... (총 123개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 5
# ==================================================
# 총 데이터 개수: 25,071
# 고유값 개수: 50
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 0                              :    6,281 (25.05%)
#  2. 21                             :    1,667 ( 6.65%)
#  3. 22                             :    1,660 ( 6.62%)
#  4. 23                             :    1,655 ( 6.60%)
#  5. 24                             :    1,634 ( 6.52%)
#  6. 25                             :    1,594 ( 6.36%)
#  7. 26                             :    1,517 ( 6.05%)
#  8. 27                             :    1,407 ( 5.61%)
#  9. 28                             :    1,265 ( 5.05%)
# 10. 29                             :    1,098 ( 4.38%)
# 11. 30                             :      946 ( 3.77%)
# 12. 31                             :      802 ( 3.20%)
# 13. 32                             :      667 ( 2.66%)
# 14. 33                             :      549 ( 2.19%)
# 15. 34                             :      440 ( 1.76%)
# 16. 35                             :      341 ( 1.36%)
# 17. 36                             :      281 ( 1.12%)
# ...
#
# 컬럼 12: 모든 값이 결측값입니다.
#
# ================================================================================
# ADM_DONG_CD 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: ZIP_CD
# ################################################################################
# 데이터 형태: (69675, 5)
# 컬럼 수: 5
# 행 수: 69,675
#
# ==================================================
# 수치형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 69,675
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 239,168.61
# 중앙값: 100,793.00
# 표준편차: 248,916.66
# 최솟값: 0.00
# 최댓값: 799,823.00
# 25% 분위수: 32,001.50
# 50% 분위수: 100,793.00
# 75% 분위수: 449,595.50
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 69,675
# 고유값 개수: 18
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 18개 카테고리:
# ------------------------------
#  1. 경기                             :   13,533 (19.42%)
#  2. 서울                             :   11,930 (17.12%)
#  3. 경북                             :    5,496 ( 7.89%)
#  4. 경남                             :    4,850 ( 6.96%)
#  5. 부산                             :    4,463 ( 6.41%)
#  6. 전남                             :    3,912 ( 5.61%)
#  7. 충남                             :    3,447 ( 4.95%)
#  8. 강원                             :    3,440 ( 4.94%)
#  9. 전북                             :    3,371 ( 4.84%)
# 10. 대구                             :    3,104 ( 4.45%)
# 11. 충북                             :    2,840 ( 4.08%)
# 12. 인천                             :    2,669 ( 3.83%)
# 13. 광주                             :    2,091 ( 3.00%)
# 14. 대전                             :    1,970 ( 2.83%)
# 15. 울산                             :    1,215 ( 1.74%)
# 16. 제주                             :    1,070 ( 1.54%)
# 17. 세종                             :      273 ( 0.39%)
# 18. 주소미상                           :        1 ( 0.00%)
#
# ==================================================
# 범주형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 69,402
# 고유값 개수: 301
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 중구                             :    1,897 ( 2.73%)
#  2. 서구                             :    1,763 ( 2.54%)
#  3. 동구                             :    1,746 ( 2.52%)
#  4. 북구                             :    1,532 ( 2.21%)
#  5. 남구                             :    1,505 ( 2.17%)
#  6. 강남구                            :      806 ( 1.16%)
#  7. 강서구                            :      722 ( 1.04%)
#  8. 화성시                            :      711 ( 1.02%)
#  9. 제주시                            :      701 ( 1.01%)
# 10. 송파구                            :      648 ( 0.93%)
# 11. 구미시                            :      612 ( 0.88%)
# 12. 서초구                            :      604 ( 0.87%)
# 13. 영등포구                           :      599 ( 0.86%)
# 14. 노원구                            :      590 ( 0.85%)
# 15. 평택시                            :      585 ( 0.84%)
# 16. 남양주시                           :      573 ( 0.83%)
# 17. 마포구                            :      567 ( 0.82%)
# 18. 수성구                            :      553 ( 0.80%)
# 19. 광산구                            :      543 ( 0.78%)
# 20. 부산진구                           :      529 ( 0.76%)
#
# ... (총 301개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 69,674
# 고유값 개수: 5,960
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 중동                             :      201 ( 0.29%)
#  2. 중앙동                            :      181 ( 0.26%)
#  3. 교동                             :      168 ( 0.24%)
#  4. 남면                             :      164 ( 0.24%)
#  5. 송정동                            :      163 ( 0.23%)
#  6. 여의도동                           :      158 ( 0.23%)
#  7. 금곡동                            :      142 ( 0.20%)
#  8. 북면                             :      130 ( 0.19%)
#  9. 부곡동                            :      126 ( 0.18%)
# 10. 상동                             :      120 ( 0.17%)
# 11. 서면                             :      118 ( 0.17%)
# 12. 화곡동                            :      106 ( 0.15%)
# 13. 논현동                            :      104 ( 0.15%)
# 14. 서울중앙우체국사서함                     :      101 ( 0.14%)
# 15. 내동                             :      101 ( 0.14%)
# 16. 동천동                            :       99 ( 0.14%)
# 17. 신월동                            :       99 ( 0.14%)
# 18. 고잔동                            :       95 ( 0.14%)
# 19. 금호동                            :       94 ( 0.13%)
# 20. 미아동                            :       94 ( 0.13%)
#
# ... (총 5960개 카테고리 중 상위 20개만 표시)
#
# 컬럼 5: 모든 값이 결측값입니다.
#
# ================================================================================
# ZIP_CD 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: BRANCH_CD
# ################################################################################
# 데이터 형태: (1130, 6)
# 컬럼 수: 6
# 행 수: 1,130
#
# ==================================================
# 수치형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 1,130
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 5,094.08
# 중앙값: 5,402.50
# 표준편차: 3,156.08
# 최솟값: 3.00
# 최댓값: 9,984.00
# 25% 분위수: 2,217.75
# 50% 분위수: 5,402.50
# 75% 분위수: 7,986.25
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 1,130
# 고유값 개수: 1,113
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 임시부점코드                         :        3 ( 0.27%)
#  2. 전략기획부                          :        2 ( 0.18%)
#  3. 업무지원센터                         :        2 ( 0.18%)
#  4. 직원만족부                          :        2 ( 0.18%)
#  5. 준법추진부                          :        2 ( 0.18%)
#  6. 리스크관리부                         :        2 ( 0.18%)
#  7. HR부                            :        2 ( 0.18%)
#  8. 소비자보호부                         :        2 ( 0.18%)
#  9. 재무기획부                          :        2 ( 0.18%)
# 10. 총무부                            :        2 ( 0.18%)
# 11. 회계부                            :        2 ( 0.18%)
# 12. 자금부                            :        2 ( 0.18%)
# 13. 테크기획부                          :        2 ( 0.18%)
# 14. 인프라시스템부                        :        2 ( 0.18%)
# 15. 노동조합                           :        2 ( 0.18%)
# 16. 브랜드홍보부                         :        2 ( 0.18%)
# 17. 원곡동외환송금센터점                     :        1 ( 0.09%)
# 18. 모바일                            :        1 ( 0.09%)
# 19. 본리동종합금융센터                      :        1 ( 0.09%)
# 20. 청주중앙                           :        1 ( 0.09%)
#
# ... (총 1113개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 수치형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 1,130
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 17,515.88
# 중앙값: 8,351.50
# 표준편차: 17,068.94
# 최솟값: 0.00
# 최댓값: 110,719.00
# 25% 분위수: 5,606.75
# 50% 분위수: 8,351.50
# 75% 분위수: 24,571.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 56
# 이상치 비율: 4.96%
# 이상치 범위: -22839.62 미만 또는 53017.38 초과
#
# ==================================================
# 범주형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 1,130
# 고유값 개수: 17
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 17개 카테고리:
# ------------------------------
#  1. 3                              :      500 (44.25%)
#  2. 1                              :      230 (20.35%)
#  3. 4                              :      164 (14.51%)
#  4. 24                             :      108 ( 9.56%)
#  5. 9                              :       24 ( 2.12%)
#  6. 6                              :       17 ( 1.50%)
#  7. 18                             :       16 ( 1.42%)
#  8. 27                             :       13 ( 1.15%)
#  9. 22                             :       13 ( 1.15%)
# 10. 2                              :       12 ( 1.06%)
# 11. 7                              :       10 ( 0.88%)
# 12. 12                             :        7 ( 0.62%)
# 13. 8                              :        6 ( 0.53%)
# 14. 5                              :        4 ( 0.35%)
# 15. 13                             :        3 ( 0.27%)
# 16. 19                             :        2 ( 0.18%)
# 17. 11                             :        1 ( 0.09%)
#
# ==================================================
# 범주형 변수 분석: 컬럼 5
# ==================================================
# 총 데이터 개수: 1,130
# 고유값 개수: 158
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1.                                :      904 (80.00%)
#  2. 1206                           :       16 ( 1.42%)
#  3. 0901                           :        9 ( 0.80%)
#  4. 3810                           :        9 ( 0.80%)
#  5. 9447                           :        6 ( 0.53%)
#  6. 5106                           :        5 ( 0.44%)
#  7. 1002                           :        4 ( 0.35%)
#  8. 3496                           :        4 ( 0.35%)
#  9. 5229                           :        4 ( 0.35%)
# 10. 3762                           :        3 ( 0.27%)
# 11. 3085                           :        3 ( 0.27%)
# 12. 6187                           :        2 ( 0.18%)
# 13. 9694                           :        2 ( 0.18%)
# 14. 0688                           :        2 ( 0.18%)
# 15. 0099                           :        2 ( 0.18%)
# 16. 4684                           :        2 ( 0.18%)
# 17. 2194                           :        2 ( 0.18%)
# 18. 7438                           :        2 ( 0.18%)
# 19. 7357                           :        2 ( 0.18%)
# 20. 6895                           :        2 ( 0.18%)
#
# ... (총 158개 카테고리 중 상위 20개만 표시)
#
# 컬럼 6: 모든 값이 결측값입니다.
#
# ================================================================================
# BRANCH_CD 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------
#
#
# ################################################################################
# 테이블: CMN_CD
# ################################################################################
# 데이터 형태: (406, 6)
# 컬럼 수: 6
# 행 수: 406
#
# ==================================================
# 범주형 변수 분석: 컬럼 1
# ==================================================
# 총 데이터 개수: 406
# 고유값 개수: 9
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 9개 카테고리:
# ------------------------------
#  1. 100697000                      :      328 (80.79%)
#  2. 101362000                      :       28 ( 6.90%)
#  3. 100233000                      :       18 ( 4.43%)
#  4. 101571000                      :       10 ( 2.46%)
#  5. 100267000                      :        7 ( 1.72%)
#  6. 112051000                      :        4 ( 0.99%)
#  7. 101523000                      :        4 ( 0.99%)
#  8. 101545000                      :        4 ( 0.99%)
#  9. 133927000                      :        3 ( 0.74%)
#
# ==================================================
# 수치형 변수 분석: 컬럼 2
# ==================================================
# 총 데이터 개수: 406
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 기술통계:
# ------------------------------
# 평균: 334.29
# 중앙값: 382.00
# 표준편차: 239.73
# 최솟값: 0.00
# 최댓값: 941.00
# 25% 분위수: 115.00
# 50% 분위수: 382.00
# 75% 분위수: 477.00
#
# 이상치 분석:
# ------------------------------
# 이상치 개수: 0
# 이상치 비율: 0.00%
#
# ==================================================
# 범주형 변수 분석: 컬럼 3
# ==================================================
# 총 데이터 개수: 406
# 고유값 개수: 30
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 19630201                       :      333 (82.02%)
#  2. 20170703                       :       18 ( 4.43%)
#  3. 20180112                       :        5 ( 1.23%)
#  4. 20120601                       :        4 ( 0.99%)
#  5. 20190518                       :        3 ( 0.74%)
#  6. 20120801                       :        3 ( 0.74%)
#  7. 20171101                       :        3 ( 0.74%)
#  8. 20250718                       :        3 ( 0.74%)
#  9. 20200613                       :        3 ( 0.74%)
# 10. 20111004                       :        2 ( 0.49%)
# 11. 20130507                       :        2 ( 0.49%)
# 12. 20180827                       :        2 ( 0.49%)
# 13. 20120114                       :        2 ( 0.49%)
# 14. 20170303                       :        2 ( 0.49%)
# 15. 20210814                       :        2 ( 0.49%)
# 16. 20101211                       :        2 ( 0.49%)
# 17. 20180622                       :        2 ( 0.49%)
# 18. 20110701                       :        2 ( 0.49%)
# 19. 20181001                       :        2 ( 0.49%)
# 20. 20181127                       :        1 ( 0.25%)
#
# ... (총 30개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 4
# ==================================================
# 총 데이터 개수: 406
# 고유값 개수: 24
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 99991231                       :      365 (89.90%)
#  2. 20170702                       :        6 ( 1.48%)
#  3. 20171031                       :        5 ( 1.23%)
#  4. 20120531                       :        4 ( 0.99%)
#  5. 20250717                       :        3 ( 0.74%)
#  6. 20101210                       :        2 ( 0.49%)
#  7. 20120113                       :        2 ( 0.49%)
#  8. 20210813                       :        2 ( 0.49%)
#  9. 20180930                       :        2 ( 0.49%)
# 10. 20200223                       :        1 ( 0.25%)
# 11. 20130418                       :        1 ( 0.25%)
# 12. 20101028                       :        1 ( 0.25%)
# 13. 20181126                       :        1 ( 0.25%)
# 14. 20220210                       :        1 ( 0.25%)
# 15. 20250320                       :        1 ( 0.25%)
# 16. 20240125                       :        1 ( 0.25%)
# 17. 20151105                       :        1 ( 0.25%)
# 18. 20201217                       :        1 ( 0.25%)
# 19. 20130506                       :        1 ( 0.25%)
# 20. 20111003                       :        1 ( 0.25%)
#
# ... (총 24개 카테고리 중 상위 20개만 표시)
#
# ==================================================
# 범주형 변수 분석: 컬럼 5
# ==================================================
# 총 데이터 개수: 406
# 고유값 개수: 399
# 결측값 개수: 0
# 결측값 비율: 0.00%
#
# 상위 20개 카테고리:
# ------------------------------
#  1. 해당무                            :        3 ( 0.74%)
#  2. 공장                             :        2 ( 0.49%)
#  3. 상품                             :        2 ( 0.49%)
#  4. 기타건물                           :        2 ( 0.49%)
#  5. 해외현지법인                         :        2 ( 0.49%)
#  6. 우리종금지급보증서                      :        2 ( 0.49%)
#  7. 어음보험증권                         :        1 ( 0.25%)
#  8. 신기술개발지원자금                      :        1 ( 0.25%)
#  9. 학자금대출신용보증서                     :        1 ( 0.25%)
# 10. 비분류특수은행지보                      :        1 ( 0.25%)
# 11. 비분류일반은행지보                      :        1 ( 0.25%)
# 12. 비분류금융기관지보                      :        1 ( 0.25%)
# 13. 전기공사공제조합보증서                    :        1 ( 0.25%)
# 14. 수출어음보험증권                       :        1 ( 0.25%)
# 15. 삼성화재보험증권                       :        1 ( 0.25%)
# 16. 대구신용보증재단신보                     :        1 ( 0.25%)
# 17. 한국산업기술평가원보증서                   :        1 ( 0.25%)
# 18. 서울신용보증재단신보                     :        1 ( 0.25%)
# 19. 대전신용보증재단신보                     :        1 ( 0.25%)
# 20. 충북신용보증재단신보                     :        1 ( 0.25%)
#
# ... (총 399개 카테고리 중 상위 20개만 표시)
#
# 컬럼 6: 모든 값이 결측값입니다.
#
# ================================================================================
# CMN_CD 테이블 분석 완료
# ================================================================================
#
#
# -------------------------------------------------- 다음 테이블로... --------------------------------------------------

# %%
# 데이터 품질 및 관계 분석 실행
if 'df_total' in locals() and len(df_total) > 0:
    print("데이터 품질 및 관계 분석 시작...")
    
    # 데이터 품질 분석
    quality_results = analyze_data_quality(df_total)
    
    # 테이블 간 관계 분석 
    print("\\n테이블 간 관계 분석을 시작합니다 (시간이 걸릴 수 있습니다)...")
    relationships = analyze_table_relationships(df_total)
    
    print("\\n" + "="*100)
    print("전체 EDA 분석이 완료되었습니다!")
    print("="*100)
    
else:
    print("df_total 딕셔너리가 정의되지 않았습니다.")
    print("먼저 데이터 로딩 셀을 실행해주세요.")
# Out:
# 데이터 품질 및 관계 분석 시작...
#
# ################################################################################
# 데이터 품질 종합 분석
# ################################################################################
#         테이블명      행수  컬럼수      총_셀수   결측_셀수 결측_비율(%) 중복_행수 중복_비율(%)
#    CORP_PROF 395,108    7 2,765,756 395,108    14.29     0     0.00
#     CUST_MST 831,796    5 4,158,980 831,796    20.00     0     0.00
# CORP_BIZ_MAP 436,688    3 1,310,064 436,688    33.33     0     0.00
#    LOAN_CTRT  25,203   14   352,842  49,079    13.91     0     0.00
#      PRD_MST   1,342    7     9,394   1,342    14.29     0     0.00
#     COLL_SET  25,203    8   201,624  25,203    12.50     0     0.00
#      CAI_TXN 254,928    4 1,019,712 254,928    25.00     0     0.00
#      KSIC_CD   1,205   11    13,255   1,205     9.09     0     0.00
#  ADM_DONG_CD  25,071   12   300,852  31,702    10.54     0     0.00
#       ZIP_CD  69,675    5   348,375  69,949    20.08     0     0.00
#    BRANCH_CD   1,130    6     6,780   1,130    16.67     0     0.00
#       CMN_CD     406    6     2,436     406    16.67     0     0.00
# \n테이블 간 관계 분석을 시작합니다 (시간이 걸릴 수 있습니다)...
#
# ################################################################################
# 테이블 간 관계 분석
# ################################################################################
# 잠재적 테이블 관계:
#         테이블1  컬럼1         테이블2 컬럼2   공통값수  겹침비율
#    CORP_PROF  컬럼4     CUST_MST 컬럼2 395108 1.000
#     CUST_MST  컬럼1 CORP_BIZ_MAP 컬럼1 436688 1.000
#     COLL_SET  컬럼7  ADM_DONG_CD 컬럼4     32 1.000
#     COLL_SET  컬럼6  ADM_DONG_CD 컬럼7   3812 1.000
#    LOAN_CTRT  컬럼8    BRANCH_CD 컬럼1    440 1.000
#    LOAN_CTRT 컬럼10     COLL_SET 컬럼2   5630 1.000
#    CORP_PROF  컬럼6     CUST_MST 컬럼2 395108 1.000
#     CUST_MST  컬럼1 CORP_BIZ_MAP 컬럼2 436688 1.000
#    LOAN_CTRT  컬럼5      PRD_MST 컬럼2    277 1.000
#  ADM_DONG_CD 컬럼10       ZIP_CD 컬럼4   4009 0.998
#    LOAN_CTRT  컬럼1     COLL_SET 컬럼1  23876 0.947
#     CUST_MST  컬럼2      CAI_TXN 컬럼1  72546 0.911
#    CORP_PROF  컬럼4      CAI_TXN 컬럼1  70560 0.887
#      KSIC_CD  컬럼7    BRANCH_CD 컬럼4     15 0.882
#    CORP_PROF  컬럼5    BRANCH_CD 컬럼3    700 0.879
#  ADM_DONG_CD  컬럼9       ZIP_CD 컬럼3    207 0.852
#      KSIC_CD  컬럼7  ADM_DONG_CD 컬럼1     17 0.850
#     CUST_MST  컬럼2      CAI_TXN 컬럼2  69564 0.849
#      KSIC_CD  컬럼7  ADM_DONG_CD 컬럼5     40 0.800
#    CORP_PROF  컬럼4      CAI_TXN 컬럼2  65260 0.797
#     CUST_MST  컬럼1    LOAN_CTRT 컬럼3  11475 0.796
# CORP_BIZ_MAP  컬럼2    LOAN_CTRT 컬럼3  11475 0.796
# CORP_BIZ_MAP  컬럼1    LOAN_CTRT 컬럼3  11475 0.796
#    CORP_PROF  컬럼1  ADM_DONG_CD 컬럼1     15 0.750
#      KSIC_CD  컬럼7  ADM_DONG_CD 컬럼2     54 0.740
#       ZIP_CD  컬럼1    BRANCH_CD 컬럼5    105 0.665
#    LOAN_CTRT  컬럼8    BRANCH_CD 컬럼5    103 0.652
#    LOAN_CTRT  컬럼8       ZIP_CD 컬럼1    275 0.625
#      KSIC_CD  컬럼3       ZIP_CD 컬럼1    307 0.613
#    CORP_PROF  컬럼1  ADM_DONG_CD 컬럼4     70 0.569
#    LOAN_CTRT 컬럼10     COLL_SET 컬럼3   3192 0.567
#    CORP_PROF  컬럼1  ADM_DONG_CD 컬럼5     28 0.560
#    CORP_PROF  컬럼5       ZIP_CD 컬럼1  26544 0.550
#    CORP_PROF  컬럼5    BRANCH_CD 컬럼5     84 0.532
#    CORP_PROF  컬럼1      KSIC_CD 컬럼7     41 0.532
#    CORP_PROF  컬럼1     COLL_SET 컬럼7     17 0.531
#    CORP_PROF  컬럼5    LOAN_CTRT 컬럼8    232 0.527
#    CORP_PROF  컬럼1  ADM_DONG_CD 컬럼2     37 0.507
#       ZIP_CD  컬럼1    BRANCH_CD 컬럼1    570 0.504
#      KSIC_CD  컬럼1       ZIP_CD 컬럼1    606 0.503
#    LOAN_CTRT  컬럼6       CMN_CD 컬럼3     15 0.500
#    LOAN_CTRT  컬럼6       CMN_CD 컬럼4     12 0.500
#    CORP_PROF  컬럼5      KSIC_CD 컬럼3    248 0.495
#    LOAN_CTRT  컬럼6      PRD_MST 컬럼6     40 0.494
#    CORP_PROF  컬럼1      KSIC_CD 컬럼5    111 0.474
#    CORP_PROF  컬럼5    BRANCH_CD 컬럼1    480 0.425
#    CORP_PROF  컬럼5      KSIC_CD 컬럼1    448 0.372
#    LOAN_CTRT  컬럼6      PRD_MST 컬럼5    195 0.360
#      KSIC_CD  컬럼5  ADM_DONG_CD 컬럼4     42 0.341
#    CORP_PROF  컬럼1    BRANCH_CD 컬럼1    356 0.315
#    CORP_PROF  컬럼1    LOAN_CTRT 컬럼8    137 0.311
#    CORP_PROF  컬럼1      KSIC_CD 컬럼3    146 0.291
#  ADM_DONG_CD  컬럼2    BRANCH_CD 컬럼1     18 0.247
#  ADM_DONG_CD  컬럼4    BRANCH_CD 컬럼1     29 0.236
#    CORP_PROF  컬럼1    BRANCH_CD 컬럼5     37 0.234
#    CORP_PROF  컬럼1      KSIC_CD 컬럼1    276 0.229
#      KSIC_CD  컬럼7    BRANCH_CD 컬럼1     16 0.208
#      KSIC_CD  컬럼5  ADM_DONG_CD 컬럼2     13 0.178
#      KSIC_CD  컬럼5    BRANCH_CD 컬럼1     40 0.171
#    CORP_PROF  컬럼1       ZIP_CD 컬럼1   9766 0.140
#      KSIC_CD  컬럼3  ADM_DONG_CD 컬럼4     15 0.122
#      KSIC_CD  컬럼3    BRANCH_CD 컬럼1     59 0.118
#       ZIP_CD  컬럼4    BRANCH_CD 컬럼2    114 0.102
# \n====================================================================================================
# 전체 EDA 분석이 완료되었습니다!
# ====================================================================================================

# %%
# 개별 테이블 선택적 분석 (필요시 사용)
def analyze_specific_table(table_name, df_total):
    """
    특정 테이블만 선택해서 분석
    """
    if table_name in df_total:
        print(f"{table_name} 테이블 개별 분석")
        perform_table_eda(df_total[table_name], table_name)
    else:
        print(f"테이블 '{table_name}'을 찾을 수 없습니다.")
        print(f"사용 가능한 테이블: {list(df_total.keys())}")

# 사용 예시 (필요한 테이블명으로 변경)
# analyze_specific_table('CORP_PROF', df_total)
# analyze_specific_table('LOAN_CTRT', df_total)

print("개별 테이블 분석을 원하시면 위의 주석을 해제하고 테이블명을 지정해서 실행하세요.")
print(f"사용 가능한 테이블: {list(df_total.keys()) if 'df_total' in locals() else '데이터를 먼저 로드하세요'}")
# Out:
# 개별 테이블 분석을 원하시면 위의 주석을 해제하고 테이블명을 지정해서 실행하세요.
# 사용 가능한 테이블: ['CORP_PROF', 'CUST_MST', 'CORP_BIZ_MAP', 'LOAN_CTRT', 'PRD_MST', 'COLL_SET', 'CAI_TXN', 'KSIC_CD', 'ADM_DONG_CD', 'ZIP_CD', 'BRANCH_CD', 'CMN_CD']

# %%
# EDA 분석 함수 정의
def analyze_nominal_variable(series, var_name, max_categories=20):
    """
    Nominal (범주형) 변수 분석
    """
    print(f"\n{'='*50}")
    print(f"범주형 변수 분석: {var_name}")
    print(f"{'='*50}")
    
    # 기본 정보
    print(f"총 데이터 개수: {len(series):,}")
    print(f"고유값 개수: {series.nunique():,}")
    print(f"결측값 개수: {series.isnull().sum():,}")
    print(f"결측값 비율: {series.isnull().mean()*100:.2f}%")
    
    # 빈도 분석
    value_counts = series.value_counts()
    print(f"\n상위 {min(max_categories, len(value_counts))}개 카테고리:")
    print("-" * 30)
    
    for i, (value, count) in enumerate(value_counts.head(max_categories).items()):
        percentage = (count / len(series)) * 100
        print(f"{i+1:2d}. {str(value)[:30]:30s} : {count:8,} ({percentage:5.2f}%)")
    
    # 분포 특성
    if len(value_counts) > max_categories:
        print(f"\n... (총 {len(value_counts)}개 카테고리 중 상위 {max_categories}개만 표시)")
    
    return value_counts

def analyze_numerical_variable(series, var_name):
    """
    Numerical (수치형) 변수 분석
    """
    print(f"\n{'='*50}")
    print(f"수치형 변수 분석: {var_name}")
    print(f"{'='*50}")
    
    # 기본 정보
    print(f"총 데이터 개수: {len(series):,}")
    print(f"결측값 개수: {series.isnull().sum():,}")
    print(f"결측값 비율: {series.isnull().mean()*100:.2f}%")
    
    # 수치형으로 변환 가능한지 확인
    try:
        numeric_series = pd.to_numeric(series, errors='coerce')
        
        if numeric_series.isnull().all():
            print("수치형으로 변환할 수 없는 데이터입니다.")
            return analyze_nominal_variable(series, var_name)
        
        # 기술통계
        print(f"\n기술통계:")
        print("-" * 30)
        print(f"평균: {numeric_series.mean():,.2f}")
        print(f"중앙값: {numeric_series.median():,.2f}")
        print(f"표준편차: {numeric_series.std():,.2f}")
        print(f"최솟값: {numeric_series.min():,.2f}")
        print(f"최댓값: {numeric_series.max():,.2f}")
        
        # 분위수
        quantiles = numeric_series.quantile([0.25, 0.5, 0.75])
        print(f"25% 분위수: {quantiles[0.25]:,.2f}")
        print(f"50% 분위수: {quantiles[0.5]:,.2f}")
        print(f"75% 분위수: {quantiles[0.75]:,.2f}")
        
        # 이상치 탐지 (IQR 방법)
        Q1 = quantiles[0.25]
        Q3 = quantiles[0.75]
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        outliers = numeric_series[(numeric_series < lower_bound) | (numeric_series > upper_bound)]
        print(f"\n이상치 분석:")
        print("-" * 30)
        print(f"이상치 개수: {len(outliers):,}")
        print(f"이상치 비율: {len(outliers)/len(numeric_series)*100:.2f}%")
        
        if len(outliers) > 0:
            print(f"이상치 범위: {lower_bound:.2f} 미만 또는 {upper_bound:.2f} 초과")
        
        return numeric_series
        
    except Exception as e:
        print(f"수치형 분석 중 오류: {e}")
        return analyze_nominal_variable(series, var_name)

def detect_variable_type(series, var_name):
    """
    변수 타입을 자동으로 감지 (nominal vs numerical)
    """
    # 고유값 비율로 판단
    unique_ratio = series.nunique() / len(series)
    
    # 수치형으로 변환 시도
    try:
        numeric_series = pd.to_numeric(series, errors='coerce')
        numeric_ratio = (~numeric_series.isnull()).mean()
        
        # 판단 기준
        if numeric_ratio > 0.8 and unique_ratio > 0.1:  # 80% 이상이 숫자이고, 고유값 비율이 10% 이상
            return 'numerical'
        else:
            return 'nominal'
    except:
        return 'nominal'

# %%
# EDA 분석을 위한 추가 라이브러리 import
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# 한글 폰트 설정 (matplotlib)
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['axes.unicode_minus'] = False

# 시각화 스타일 설정
sns.set_style("whitegrid")
plt.style.use('default')

# %%
# 각 테이블별 전체 EDA 실행 함수
def perform_table_eda(df, table_name):
    """
    테이블별 종합 EDA 수행
    """
    print(f"\n{'#'*80}")
    print(f"테이블: {table_name}")
    print(f"{'#'*80}")
    
    print(f"데이터 형태: {df.shape}")
    print(f"컬럼 수: {df.shape[1]}")
    print(f"행 수: {df.shape[0]:,}")
    
    # 각 컬럼별 분석
    for col_idx, col in enumerate(df.columns):
        series = df[col].dropna()  # 결측값 제거 후 분석
        
        if len(series) == 0:
            print(f"\n컬럼 {col_idx + 1}: 모든 값이 결측값입니다.")
            continue
        
        # 변수 타입 자동 감지
        var_type = detect_variable_type(series, f"컬럼 {col_idx + 1}")
        
        if var_type == 'numerical':
            analyze_numerical_variable(series, f"컬럼 {col_idx + 1}")
        else:
            analyze_nominal_variable(series, f"컬럼 {col_idx + 1}")
    
    print(f"\n{'='*80}")
    print(f"{table_name} 테이블 분석 완료")
    print(f"{'='*80}\n")

# 데이터 품질 분석 함수
def analyze_data_quality(df_total):
    """
    전체 데이터 품질 분석
    """
    print(f"\n{'#'*80}")
    print("데이터 품질 종합 분석")
    print(f"{'#'*80}")
    
    quality_summary = []
    
    for table_name, df in df_total.items():
        # 기본 정보
        total_cells = df.shape[0] * df.shape[1]
        missing_cells = df.isnull().sum().sum()
        missing_percentage = (missing_cells / total_cells) * 100
        
        # 중복 행 확인
        duplicate_rows = df.duplicated().sum()
        duplicate_percentage = (duplicate_rows / len(df)) * 100
        
        quality_summary.append({
            '테이블명': table_name,
            '행수': f"{df.shape[0]:,}",
            '컬럼수': df.shape[1],
            '총_셀수': f"{total_cells:,}",
            '결측_셀수': f"{missing_cells:,}",
            '결측_비율(%)': f"{missing_percentage:.2f}",
            '중복_행수': f"{duplicate_rows:,}",
            '중복_비율(%)': f"{duplicate_percentage:.2f}"
        })
    
    # 품질 요약 테이블 출력
    quality_df = pd.DataFrame(quality_summary)
    print(quality_df.to_string(index=False))
    
    return quality_df

# 테이블 간 관계 분석 함수
def analyze_table_relationships(df_total):
    """
    테이블 간 관계 분석 (공통 컬럼 및 값 기반)
    """
    print(f"\n{'#'*80}")
    print("테이블 간 관계 분석")
    print(f"{'#'*80}")
    
    tables = list(df_total.keys())
    relationships = []
    
    # 각 테이블 쌍에 대해 공통 값 분석
    for i, table1 in enumerate(tables):
        for j, table2 in enumerate(tables[i+1:], i+1):
            df1, df2 = df_total[table1], df_total[table2]
            
            # 각 컬럼 조합에서 공통 값 찾기
            for col1_idx in range(df1.shape[1]):
                for col2_idx in range(df2.shape[1]):
                    try:
                        col1_values = set(df1.iloc[:, col1_idx].dropna().astype(str))
                        col2_values = set(df2.iloc[:, col2_idx].dropna().astype(str))
                        
                        common_values = col1_values.intersection(col2_values)
                        
                        if len(common_values) > 0:
                            overlap_ratio = len(common_values) / min(len(col1_values), len(col2_values))
                            
                            # 의미있는 관계로 판단되는 기준
                            if overlap_ratio > 0.1 and len(common_values) > 10:
                                relationships.append({
                                    '테이블1': table1,
                                    '컬럼1': f"컬럼{col1_idx+1}",
                                    '테이블2': table2,
                                    '컬럼2': f"컬럼{col2_idx+1}",
                                    '공통값수': len(common_values),
                                    '겹침비율': f"{overlap_ratio:.3f}"
                                })
                    except Exception as e:
                        continue
    
    if relationships:
        rel_df = pd.DataFrame(relationships)
        rel_df = rel_df.sort_values('겹침비율', ascending=False)
        print("잠재적 테이블 관계:")
        print(rel_df.to_string(index=False))
    else:
        print("명확한 테이블 간 관계를 찾을 수 없습니다.")
    
    return relationships

# %% [markdown]
# # 상세 탐색적 데이터 분석 (EDA)
#
# 이제 각 테이블별로 상세한 EDA를 진행합니다.
# - **Nominal 변수**: 범주형 데이터의 빈도 분석, 고유값 확인
# - **Numerical 변수**: 기술통계, 분포 분석, 이상치 탐지

# %%
# 6단계: EDA 결과 종합 분석 및 인사이트
print("\n" + "=" * 100)
print("6단계: EDA 결과 종합 분석 및 주요 인사이트")
print("=" * 100)

# 수치형 변수들의 요약 통계
numerical_summary = []

if 'df_total' in locals():
    print(f"\n{'='*60}")
    print("주요 수치형 변수 요약")
    print(f"{'='*60}")
    
    # LOAN_CTRT 대줄잔액 요약
    if 'LOAN_CTRT' in df_total:
        loan_amounts = pd.to_numeric(df_total['LOAN_CTRT'].iloc[:, 9], errors='coerce')
        numerical_summary.append({
            '변수명': '대줄잔액',
            '테이블': 'LOAN_CTRT',
            '평균': f"{loan_amounts.mean():,.0f}원",
            '중앙값': f"{loan_amounts.median():,.0f}원",
            '최댓값': f"{loan_amounts.max():,.0f}원",
            '표준편차': f"{loan_amounts.std():,.0f}원"
        })
    
    # COLL_SET 담보평가금액 요약
    if 'COLL_SET' in df_total:
        coll_amounts = pd.to_numeric(df_total['COLL_SET'].iloc[:, 2], errors='coerce')
        numerical_summary.append({
            '변수명': '담보평가금액',
            '테이블': 'COLL_SET', 
            '평균': f"{coll_amounts.mean():,.0f}원",
            '중앙값': f"{coll_amounts.median():,.0f}원",
            '최댓값': f"{coll_amounts.max():,.0f}원",
            '표준편차': f"{coll_amounts.std():,.0f}원"
        })
        
        # LTV 분석
        ltv_values = pd.to_numeric(df_total['COLL_SET'].iloc[:, 3], errors='coerce')
        numerical_summary.append({
            '변수명': 'LTV비율',
            '테이블': 'COLL_SET',
            '평균': f"{ltv_values.mean():.2f}%",
            '중앙값': f"{ltv_values.median():.2f}%", 
            '최댓값': f"{ltv_values.max():.2f}%",
            '표준편차': f"{ltv_values.std():.2f}%"
        })
    
    # CAI_TXN 매출거래금액 요약
    if 'CAI_TXN' in df_total:
        txn_amounts = pd.to_numeric(df_total['CAI_TXN'].iloc[:, 2], errors='coerce')
        numerical_summary.append({
            '변수명': '매출거래금액',
            '테이블': 'CAI_TXN',
            '평균': f"{txn_amounts.mean():,.0f}원",
            '중앙값': f"{txn_amounts.median():,.0f}원", 
            '최댓값': f"{txn_amounts.max():,.0f}원",
            '표준편차': f"{txn_amounts.std():,.0f}원"
        })
    
    # 요약 테이블 출력
    if numerical_summary:
        summary_df = pd.DataFrame(numerical_summary)
        print(summary_df.to_string(index=False))
    
    # 주요 인사이트
    print(f"\n{'='*60}")
    print("주요 발견 인사이트")
    print(f"{'='*60}")
    
    insights = [
        "🏦 대출 포트폴리오 분석:",
        f"   - 총 대출 계약 수: {df_total['LOAN_CTRT'].shape[0]:,}건" if 'LOAN_CTRT' in df_total else "",
        f"   - 총 담보 설정 수: {df_total['COLL_SET'].shape[0]:,}건" if 'COLL_SET' in df_total else "",
        "",
        "🏢 기업 데이터 현황:",
        f"   - 등록 기업 수: {df_total['CORP_PROF'].shape[0]:,}개" if 'CORP_PROF' in df_total else "",
        f"   - B2B 거래 관계: {df_total['CAI_TXN'].shape[0]:,}건" if 'CAI_TXN' in df_total else "",
        "",
        "📊 데이터 품질 특징:",
        "   - 대부분 테이블이 cp949 인코딩",
        "   - 마지막 컬럼에 결측값 집중",
        "   - 수치형/범주형 변수 혼재"
    ]
    
    for insight in insights:
        if insight:  # 빈 문자열이 아닌 경우만 출력
            print(insight)

print(f"\n{'='*100}")
print("상세 EDA 분석 완료!")
print(f"{'='*100}")

# %%
# 5단계: 코드 테이블들 상세 분석
print("\n" + "=" * 100)
print("5단계: 코드 테이블들 (KSIC_CD, ADM_DONG_CD, ZIP_CD) 상세 EDA")
print("=" * 100)

# KSIC_CD (표준산업분류코드) 분석
if 'df_total' in locals() and 'KSIC_CD' in df_total:
    ksic_cd = df_total['KSIC_CD']
    
    print(f"\n{'='*60}")
    print("KSIC_CD (표준산업분류코드) 분석")
    print(f"{'='*60}")
    print(f"테이블 크기: {ksic_cd.shape[0]:,}행 x {ksic_cd.shape[1]}열")
    
    # 대분류코드
    print("\n[컬럼 9: 대분류코드]")
    analyze_nominal_variable(ksic_cd.iloc[:, 8], "대분류코드", max_categories=25)
    
    # 대분류명
    print("\n[컬럼 10: 대분류명]")
    analyze_nominal_variable(ksic_cd.iloc[:, 9], "대분류명", max_categories=25)

# ADM_DONG_CD (법정동행정구역) 분석  
if 'df_total' in locals() and 'ADM_DONG_CD' in df_total:
    adm_dong = df_total['ADM_DONG_CD']
    
    print(f"\n{'='*60}")
    print("ADM_DONG_CD (법정동행정구역) 분석")
    print(f"{'='*60}")
    print(f"테이블 크기: {adm_dong.shape[0]:,}행 x {adm_dong.shape[1]}열")
    
    # 광역시도명
    print("\n[컬럼 8: 광역시도명]")
    analyze_nominal_variable(adm_dong.iloc[:, 7], "광역시도명", max_categories=20)
    
    # 시군구명
    print("\n[컬럼 9: 시군구명]") 
    analyze_nominal_variable(adm_dong.iloc[:, 8], "시군구명", max_categories=20)

# ZIP_CD (우편번호) 분석
if 'df_total' in locals() and 'ZIP_CD' in df_total:
    zip_cd = df_total['ZIP_CD']
    
    print(f"\n{'='*60}")
    print("ZIP_CD (우편번호) 분석")
    print(f"{'='*60}")
    print(f"테이블 크기: {zip_cd.shape[0]:,}행 x {zip_cd.shape[1]}열")
    
    # 우편번호
    print("\n[컬럼 1: 우편번호]")
    analyze_numerical_variable(zip_cd.iloc[:, 0], "우편번호")
    
    # 한글시도명
    print("\n[컬럼 2: 한글시도명]")
    analyze_nominal_variable(zip_cd.iloc[:, 1], "한글시도명", max_categories=20)

# %%
# 4단계: CAI_TXN 테이블 상세 분석 (기업간거래관계)
print("\n" + "=" * 100)
print("4단계: CAI_TXN (기업간거래관계분석) 테이블 상세 EDA")
print("=" * 100)

if 'df_total' in locals() and 'CAI_TXN' in df_total:
    cai_txn = df_total['CAI_TXN']
    
    print(f"테이블 크기: {cai_txn.shape[0]:,}행 x {cai_txn.shape[1]}열")
    print(f"메모리 사용량: {cai_txn.memory_usage(deep=True).sum() / (1024**2):.2f} MB")
    
    print(f"\n{'='*60}")
    print("CAI_TXN 기업간 거래 분석")
    print(f"{'='*60}")
    
    # 판매사업자번호
    print("\n[컬럼 1: 판매사업자번호]")
    analyze_nominal_variable(cai_txn.iloc[:, 0], "판매사업자번호", max_categories=15)
    
    # 구매사업자번호  
    print("\n[컬럼 2: 구매사업자번호]")
    analyze_nominal_variable(cai_txn.iloc[:, 1], "구매사업자번호", max_categories=15)
    
    # 매출거래금액 (핵심 수치 변수)
    print("\n[컬럼 3: 매출거래금액]")
    analyze_numerical_variable(cai_txn.iloc[:, 2], "매출거래금액")
    
else:
    print("CAI_TXN 테이블을 찾을 수 없습니다.")

# %%
# 3단계: COLL_SET 테이블 상세 분석 (담보 데이터)
print("\n" + "=" * 100)
print("3단계: COLL_SET (담보설정) 테이블 상세 EDA")
print("=" * 100)

if 'df_total' in locals() and 'COLL_SET' in df_total:
    coll_set = df_total['COLL_SET']
    
    print(f"테이블 크기: {coll_set.shape[0]:,}행 x {coll_set.shape[1]}열")
    print(f"메모리 사용량: {coll_set.memory_usage(deep=True).sum() / (1024**2):.2f} MB")
    
    # 담보 관련 핵심 지표 분석
    print(f"\n{'='*60}")
    print("COLL_SET 담보 관련 핵심 지표 분석")
    print(f"{'='*60}")
    
    # 담보여신계좌번호
    print("\n[컬럼 1: 담보여신계좌번호]")
    analyze_nominal_variable(coll_set.iloc[:, 0], "담보여신계좌번호", max_categories=10)
    
    # 대출잔액
    print("\n[컬럼 2: 대출잔액]")
    analyze_numerical_variable(coll_set.iloc[:, 1], "대출잔액")
    
    # 담보평가금액
    print("\n[컬럼 3: 담보평가금액]")
    analyze_numerical_variable(coll_set.iloc[:, 2], "담보평가금액")
    
    # 담보대대출비율 (LTV - 중요한 리스크 지표)
    print("\n[컬럼 4: 담보대대출비율(LTV)]")
    analyze_numerical_variable(coll_set.iloc[:, 3], "담보대대출비율(LTV)")
    
    # 법정동코드 (지역 분석)
    print("\n[컬럼 6: 법정동코드]")
    analyze_nominal_variable(coll_set.iloc[:, 5], "법정동코드", max_categories=15)
    
    # 주담보구분
    print("\n[컬럼 7: 주담보구분]")
    analyze_nominal_variable(coll_set.iloc[:, 6], "주담보구분", max_categories=10)
    
else:
    print("COLL_SET 테이블을 찾을 수 없습니다.")

# %%
# 2단계: LOAN_CTRT 테이블 상세 분석
print("\n" + "=" * 100)
print("2단계: LOAN_CTRT (여신계약) 테이블 상세 EDA")
print("=" * 100)

if 'df_total' in locals() and 'LOAN_CTRT' in df_total:
    loan_ctrt = df_total['LOAN_CTRT']
    
    print(f"테이블 크기: {loan_ctrt.shape[0]:,}행 x {loan_ctrt.shape[1]}열")
    print(f"메모리 사용량: {loan_ctrt.memory_usage(deep=True).sum() / (1024**2):.2f} MB")
    
    # 주요 컬럼 분석
    print(f"\n{'='*60}")
    print("LOAN_CTRT 주요 컬럼 분석")
    print(f"{'='*60}")
    
    # 계좌번호
    print("\n[컬럼 1: 계좌번호]")
    analyze_nominal_variable(loan_ctrt.iloc[:, 0], "계좌번호", max_categories=10)
    
    # 계약자고객식별자
    print("\n[컬럼 3: 계약자고객식별자]")
    analyze_nominal_variable(loan_ctrt.iloc[:, 2], "계약자고객식별자", max_categories=10)
    
    # 상품코드
    print("\n[컬럼 5: 상품코드]")
    analyze_nominal_variable(loan_ctrt.iloc[:, 4], "상품코드", max_categories=15)
    
    # 대줄잔액 (핵심 수치 변수)
    print("\n[컬럼 10: 대줄잔액]")
    analyze_numerical_variable(loan_ctrt.iloc[:, 9], "대줄잔액")
    
    # 관리부점코드
    print("\n[컬럼 8: 관리부점코드]")
    analyze_nominal_variable(loan_ctrt.iloc[:, 7], "관리부점코드", max_categories=15)
    
    # 통화코드
    print("\n[컬럼 9: 통화코드]")
    analyze_nominal_variable(loan_ctrt.iloc[:, 8], "통화코드", max_categories=10)
    
else:
    print("LOAN_CTRT 테이블을 찾을 수 없습니다.")

# %%
# 1단계: CORP_PROF 테이블 상세 분석
print("=" * 100)
print("1단계: CORP_PROF (기업개황) 테이블 상세 EDA")
print("=" * 100)

if 'df_total' in locals() and 'CORP_PROF' in df_total:
    corp_prof = df_total['CORP_PROF']
    
    print(f"테이블 크기: {corp_prof.shape[0]:,}행 x {corp_prof.shape[1]}열")
    print(f"메모리 사용량: {corp_prof.memory_usage(deep=True).sum() / (1024**2):.2f} MB")
    
    # 각 컬럼별 상세 분석
    print(f"\n{'='*60}")
    print("CORP_PROF 컬럼별 분석")
    print(f"{'='*60}")
    
    # 컬럼 1: 기업식별자
    print("\n[컬럼 1: 기업식별자]")
    analyze_numerical_variable(corp_prof.iloc[:, 0], "기업식별자")
    
    # 컬럼 2: 크레탑업체명  
    print("\n[컬럼 2: 크레탑업체명]")
    analyze_nominal_variable(corp_prof.iloc[:, 1], "크레탑업체명", max_categories=15)
    
    # 컬럼 3: 크레탑업종구분
    print("\n[컬럼 3: 크레탑업종구분]") 
    analyze_nominal_variable(corp_prof.iloc[:, 2], "크레탑업종구분", max_categories=20)
    
    # 컬럼 4: 사업자번호
    print("\n[컬럼 4: 사업자번호]")
    analyze_numerical_variable(corp_prof.iloc[:, 3], "사업자번호")
    
    # 컬럼 5: 소재지우편번호
    print("\n[컬럼 5: 소재지우편번호]")
    analyze_nominal_variable(corp_prof.iloc[:, 4], "소재지우편번호", max_categories=15)
    
    # 컬럼 6: 법인등록번호
    print("\n[컬럼 6: 법인등록번호]")
    analyze_numerical_variable(corp_prof.iloc[:, 5], "법인등록번호")
    
else:
    print("CORP_PROF 테이블을 찾을 수 없습니다.")
